# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumanth-968/Array-Variable-Function/blob/main/TrOCR/Fine_tune_TrOCR_on_IAM_Handwriting_Database_using_native_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Fine-tune TrOCR on the IAM Handwriting Database
#
# In this notebook, we are going to fine-tune a pre-trained TrOCR model on the [IAM Handwriting Database](https://fki.tic.heia-fr.ch/databases/iam-handwriting-database), a collection of annotated images of handwritten text.
#
# We will do this using the new `VisionEncoderDecoderModel` class, which can be used to combine any image Transformer encoder (such as ViT, BEiT) with any text Transformer as decoder (such as BERT, RoBERTa, GPT-2). TrOCR is an instance of this, as it has an encoder-decoder architecture, with the weights of the encoder initialized from a pre-trained BEiT, and the weights of the decoder initialized from a pre-trained RoBERTa. The weights of the cross-attention layer were randomly initialized, before the authors pre-trained the model further on millions of (partially synthetic) annotated images of handwritten text.
#
# This figure gives a good overview of the model (from the original paper):
#
# ![Schermafbeelding 2021-10-26 om 16.09.25.png](data:image/png;base64,...)
#
# * TrOCR paper: https://arxiv.org/abs/2109.10282
# * TrOCR documentation: https://huggingface.co/transformers/master/model_doc/trocr.html
#
#
# Note that Patrick also wrote a very good [blog post](https://huggingface.co/blog/warm-starting-encoder-decoder) on warm-starting encoder-decoder models (which is what the TrOCR authors did). This blog post was very helpful for me to create this notebook.
#
# We will fine-tune the model using native PyTorch.
#
#
#
# ## Set-up environment
#
# First, let's install the required libraries:
# * Transformers (for the TrOCR model)
# * Datasets & Jiwer (for the evaluation metric)
#
# We will not be using HuggingFace Datasets in this notebook for data preprocessing, we will just create a good old basic PyTorch Dataset.

# %%
# !pip install -q transformers

# %%
# !pip install -q datasets jiwer
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 32.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 96.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d changheonkim/iam-trocr
# !unzip iam-trocr.zip -d iam-trocr
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Dataset URL: https://www.kaggle.com/datasets/changheonkim/iam-trocr
# License(s): unknown
# Downloading iam-trocr.zip to /content
#  97% 87.0M/90.1M [00:05<00:00, 19.9MB/s]
# 100% 90.1M/90.1M [00:05<00:00, 16.2MB/s]
# Archive:  iam-trocr.zip
#   inflating: iam-trocr/IAM/gpt2.dict.txt
#   inflating: iam-trocr/IAM/gt_test.txt
#   inflating: iam-trocr/IAM/image/c04-110-00.jpg
#   inflating: iam-trocr/IAM/image/c04-110-01.jpg
#   inflating: iam-trocr/IAM/image/c04-110-02.jpg
#   inflating: iam-trocr/IAM/image/c04-110-03.jpg
#   inflating: iam-trocr/IAM/image/c04-116-00.jpg
#   inflating: iam-trocr/IAM/image/c04-116-01.jpg
#   inflating: iam-trocr/IAM/image/c04-116-02.jpg
#   inflating: iam-trocr/IAM/image/c04-116-03.jpg
#   inflating: iam-trocr/IAM/image/c04-134-00.jpg
#   inflating: iam-trocr/IAM/image/c04-134-01.jpg
#   inflating: iam-trocr/IAM/image/c04-134-02.jpg
#   inflating: iam-trocr/IAM/image/c04-134-03.jpg
#   inflating: iam-trocr/IAM/image/c04-134-04.jpg
#   inflating: iam-trocr/IAM/image/c04-134-05.jpg
#   inflating: iam-trocr/IAM/image/c04-134-06.jpg
#   inflating: iam-trocr/IAM/image/c04-139-00.jpg
#   inflating: iam-trocr/IAM/image/c04-139-01.jpg
#   inflating: iam-trocr/IAM/image/c04-139-02.jpg
#   inflating: iam-trocr/IAM/image/c04-139-03.jpg
#   inflating: iam-trocr/IAM/image/c04-139-04.jpg
#   inflating: iam-trocr/IAM/image/c04-139-05.jpg
#   inflating: iam-trocr/IAM/image/c04-139-06.jpg
#   inflating: iam-trocr/IAM/image/c04-144-00.jpg
#   inflating: iam-trocr/IAM/image/c04-144-01.jpg
#   inflating: iam-trocr/IAM/image/c04-144-02.jpg
#   inflating: iam-trocr/IAM/image/c04-144-03.jpg
#   inflating: iam-trocr/IAM/image/c04-144-04.jpg
#   inflating: iam-trocr/IAM/image/c04-144-05.jpg
#   inflating: iam-trocr/IAM/image/c04-144-06.jpg
#   inflating: iam-trocr/IAM/image/c04-144-07.jpg
#   inflating: iam-trocr/IAM/image/c04-150-00.jpg
#   inflating: iam-trocr/IAM/image/c04-150-01.jpg
#   inflating: iam-trocr/IAM/image/c04-150-02.jpg
#   inflating: iam-trocr/IAM/image/c04-150-03.jpg
#   inflating: iam-trocr/IAM/image/c04-150-04.jpg
#   inflating: iam-trocr/IAM/image/c04-150-05.jpg
#   inflating: iam-trocr/IAM/image/c04-150-06.jpg
#   inflating: iam-trocr/IAM/image/c04-150-07.jpg
#   inflating: iam-trocr/IAM/image/c04-165-00.jpg
#   inflating: iam-trocr/IAM/image/c04-165-01.jpg
#   inflating: iam-trocr/IAM/image/c04-165-02.jpg
#   inflating: iam-trocr/IAM/image/c04-165-03.jpg
#   inflating: iam-trocr/IAM/image/c04-165-04.jpg
#   inflating: iam-trocr/IAM/image/c04-165-05.jpg
#   inflating: iam-trocr/IAM/image/c04-165-06.jpg
#   inflating: iam-trocr/IAM/image/c04-165-07.jpg
#   inflating: iam-trocr/IAM/image/c04-165-08.jpg
#   inflating: iam-trocr/IAM/image/c04-170-00.jpg
#   inflating: iam-trocr/IAM/image/c04-170-01.jpg
#   inflating: iam-trocr/IAM/image/c04-170-02.jpg
#   inflating: iam-trocr/IAM/image/c04-170-03.jpg
#   inflating: iam-trocr/IAM/image/c04-170-04.jpg
#   inflating: iam-trocr/IAM/image/c06-011-00.jpg
#   inflating: iam-trocr/IAM/image/c06-011-01.jpg
#   inflating: iam-trocr/IAM/image/c06-011-02.jpg
#   inflating: iam-trocr/IAM/image/c06-011-03.jpg
#   inflating: iam-trocr/IAM/image/c06-011-04.jpg
#   inflating: iam-trocr/IAM/image/c06-011-05.jpg
#   inflating: iam-trocr/IAM/image/c06-011-06.jpg
#   inflating: iam-trocr/IAM/image/c06-011-07.jpg
#   inflating: iam-trocr/IAM/image/c06-011-08.jpg
#   inflating: iam-trocr/IAM/image/d01-016-00.jpg
#   inflating: iam-trocr/IAM/image/d01-016-01.jpg
#   inflating: iam-trocr/IAM/image/d01-016-02.jpg
#   inflating: iam-trocr/IAM/image/d01-016-03.jpg
#   inflating: iam-trocr/IAM/image/d01-019-00.jpg
#   inflating: iam-trocr/IAM/image/d01-019-01.jpg
#   inflating: iam-trocr/IAM/image/d01-019-02.jpg
#   inflating: iam-trocr/IAM/image/d01-019-03.jpg
#   inflating: iam-trocr/IAM/image/d01-019-04.jpg
#   inflating: iam-trocr/IAM/image/d01-019-05.jpg
#   inflating: iam-trocr/IAM/image/d01-049-00.jpg
#   inflating: iam-trocr/IAM/image/d01-049-01.jpg
#   inflating: iam-trocr/IAM/image/d01-049-02.jpg
#   inflating: iam-trocr/IAM/image/d01-049-03.jpg
#   inflating: iam-trocr/IAM/image/d01-049-04.jpg
#   inflating: iam-trocr/IAM/image/d01-049-05.jpg
#   inflating: iam-trocr/IAM/image/d01-049-06.jpg
#   inflating: iam-trocr/IAM/image/d01-049-07.jpg
#   inflating: iam-trocr/IAM/image/d01-049-08.jpg
#   inflating: iam-trocr/IAM/image/d01-052-00.jpg
#   inflating: iam-trocr/IAM/image/d01-052-01.jpg
#   inflating: iam-trocr/IAM/image/d01-052-02.jpg
#   inflating: iam-trocr/IAM/image/d01-052-03.jpg
#   inflating: iam-trocr/IAM/image/d01-052-04.jpg
#   inflating: iam-trocr/IAM/image/d01-052-05.jpg
#   inflating: iam-trocr/IAM/image/d01-052-06.jpg
#   inflating: iam-trocr/IAM/image/d01-052-07.jpg
#   inflating: iam-trocr/IAM/image/d01-080-00.jpg
#   inflating: iam-trocr/IAM/image/d01-080-01.jpg
#   inflating: iam-trocr/IAM/image/d01-080-02.jpg
#   inflating: iam-trocr/IAM/image/d01-080-03.jpg
#   inflating: iam-trocr/IAM/image/d01-080-04.jpg
#   inflating: iam-trocr/IAM/image/d01-080-05.jpg
#   inflating: iam-trocr/IAM/image/d01-080-06.jpg
#   inflating: iam-trocr/IAM/image/d01-080-07.jpg
#   inflating: iam-trocr/IAM/image/d01-085-00.jpg
#   inflating: iam-trocr/IAM/image/d01-085-01.jpg
#   inflating: iam-trocr/IAM/image/d01-085-02.jpg
#   inflating: iam-trocr/IAM/image/d01-085-03.jpg
#   inflating: iam-trocr/IAM/image/d01-085-04.jpg
#   inflating: iam-trocr/IAM/image/d01-085-05.jpg
#   inflating: iam-trocr/IAM/image/d01-085-06.jpg
#   inflating: iam-trocr/IAM/image/d01-098-00.jpg
#   inflating: iam-trocr/IAM/image/d01-098-01.jpg
#   inflating: iam-trocr/IAM/image/d01-098-02.jpg
#   inflating: iam-trocr/IAM/image/d01-098-03.jpg
#   inflating: iam-trocr/IAM/image/d01-098-04.jpg
#   inflating: iam-trocr/IAM/image/d01-098-05.jpg
#   inflating: iam-trocr/IAM/image/d01-098-06.jpg
#   inflating: iam-trocr/IAM/image/d01-098-07.jpg
#   inflating: iam-trocr/IAM/image/d01-104-00.jpg
#   inflating: iam-trocr/IAM/image/d01-104-01.jpg
#   inflating: iam-trocr/IAM/image/d01-104-02.jpg
#   inflating: iam-trocr/IAM/image/d01-104-03.jpg
#   inflating: iam-trocr/IAM/image/d01-104-04.jpg
#   inflating: iam-trocr/IAM/image/d01-104-05.jpg
#   inflating: iam-trocr/IAM/image/d01-104-06.jpg
#   inflating: iam-trocr/IAM/image/d01-104-07.jpg
#   inflating: iam-trocr/IAM/image/d01-104-08.jpg
#   inflating: iam-trocr/IAM/image/d01-118-00.jpg
#   inflating: iam-trocr/IAM/image/d01-118-01.jpg
#   inflating: iam-trocr/IAM/image/d01-118-02.jpg
#   inflating: iam-trocr/IAM/image/d01-118-03.jpg
#   inflating: iam-trocr/IAM/image/d01-118-04.jpg
#   inflating: iam-trocr/IAM/image/d01-118-05.jpg
#   inflating: iam-trocr/IAM/image/d01-118-06.jpg
#   inflating: iam-trocr/IAM/image/d01-123-00.jpg
#   inflating: iam-trocr/IAM/image/d01-123-01.jpg
#   inflating: iam-trocr/IAM/image/d01-123-02.jpg
#   inflating: iam-trocr/IAM/image/d01-123-03.jpg
#   inflating: iam-trocr/IAM/image/d01-123-04.jpg
#   inflating: iam-trocr/IAM/image/d01-123-05.jpg
#   inflating: iam-trocr/IAM/image/d01-123-06.jpg
#   inflating: iam-trocr/IAM/image/d01-123-07.jpg
#   inflating: iam-trocr/IAM/image/d03-117-00.jpg
#   inflating: iam-trocr/IAM/image/d03-117-01.jpg
#   inflating: iam-trocr/IAM/image/d03-117-02.jpg
#   inflating: iam-trocr/IAM/image/d03-117-03.jpg
#   inflating: iam-trocr/IAM/image/d03-117-04.jpg
#   inflating: iam-trocr/IAM/image/d03-117-05.jpg
#   inflating: iam-trocr/IAM/image/d03-117-06.jpg
#   inflating: iam-trocr/IAM/image/d03-117-07.jpg
#   inflating: iam-trocr/IAM/image/d03-117-08.jpg
#   inflating: iam-trocr/IAM/image/d04-012-00.jpg
#   inflating: iam-trocr/IAM/image/d04-012-01.jpg
#   inflating: iam-trocr/IAM/image/d04-012-02.jpg
#   inflating: iam-trocr/IAM/image/d04-012-03.jpg
#   inflating: iam-trocr/IAM/image/d04-012-04.jpg
#   inflating: iam-trocr/IAM/image/d04-012-05.jpg
#   inflating: iam-trocr/IAM/image/d04-012-06.jpg
#   inflating: iam-trocr/IAM/image/d04-012-07.jpg
#   inflating: iam-trocr/IAM/image/d04-012-08.jpg
#   inflating: iam-trocr/IAM/image/d04-012-09.jpg
#   inflating: iam-trocr/IAM/image/d04-012-10.jpg
#   inflating: iam-trocr/IAM/image/d04-016-00.jpg
#   inflating: iam-trocr/IAM/image/d04-016-01.jpg
#   inflating: iam-trocr/IAM/image/d04-016-02.jpg
#   inflating: iam-trocr/IAM/image/d04-016-03.jpg
#   inflating: iam-trocr/IAM/image/d04-016-04.jpg
#   inflating: iam-trocr/IAM/image/d04-016-05.jpg
#   inflating: iam-trocr/IAM/image/d04-016-06.jpg
#   inflating: iam-trocr/IAM/image/d04-016-07.jpg
#   inflating: iam-trocr/IAM/image/d04-016-08.jpg
#   inflating: iam-trocr/IAM/image/d04-021-00.jpg
#   inflating: iam-trocr/IAM/image/d04-021-01.jpg
#   inflating: iam-trocr/IAM/image/d04-021-02.jpg
#   inflating: iam-trocr/IAM/image/d04-021-03.jpg
#   inflating: iam-trocr/IAM/image/d04-021-04.jpg
#   inflating: iam-trocr/IAM/image/d04-021-05.jpg
#   inflating: iam-trocr/IAM/image/d04-021-06.jpg
#   inflating: iam-trocr/IAM/image/d04-021-07.jpg
#   inflating: iam-trocr/IAM/image/d04-028-00.jpg
#   inflating: iam-trocr/IAM/image/d04-028-01.jpg
#   inflating: iam-trocr/IAM/image/d04-028-02.jpg
#   inflating: iam-trocr/IAM/image/d04-028-03.jpg
#   inflating: iam-trocr/IAM/image/d04-028-04.jpg
#   inflating: iam-trocr/IAM/image/d04-028-05.jpg
#   inflating: iam-trocr/IAM/image/d04-028-06.jpg
#   inflating: iam-trocr/IAM/image/d04-032-00.jpg
#   inflating: iam-trocr/IAM/image/d04-032-01.jpg
#   inflating: iam-trocr/IAM/image/d04-032-02.jpg
#   inflating: iam-trocr/IAM/image/d04-032-03.jpg
#   inflating: iam-trocr/IAM/image/d04-032-04.jpg
#   inflating: iam-trocr/IAM/image/d04-032-05.jpg
#   inflating: iam-trocr/IAM/image/d04-032-06.jpg
#   inflating: iam-trocr/IAM/image/d04-032-07.jpg
#   inflating: iam-trocr/IAM/image/d04-032-08.jpg
#   inflating: iam-trocr/IAM/image/d04-032-09.jpg
#   inflating: iam-trocr/IAM/image/d04-032-10.jpg
#   inflating: iam-trocr/IAM/image/d04-037-00.jpg
#   inflating: iam-trocr/IAM/image/d04-037-01.jpg
#   inflating: iam-trocr/IAM/image/d04-037-02.jpg
#   inflating: iam-trocr/IAM/image/d04-037-03.jpg
#   inflating: iam-trocr/IAM/image/d04-037-04.jpg
#   inflating: iam-trocr/IAM/image/d04-037-05.jpg
#   inflating: iam-trocr/IAM/image/d04-037-06.jpg
#   inflating: iam-trocr/IAM/image/d04-047-00.jpg
#   inflating: iam-trocr/IAM/image/d04-047-01.jpg
#   inflating: iam-trocr/IAM/image/d04-047-02.jpg
#   inflating: iam-trocr/IAM/image/d04-047-03.jpg
#   inflating: iam-trocr/IAM/image/d04-047-04.jpg
#   inflating: iam-trocr/IAM/image/d04-047-05.jpg
#   inflating: iam-trocr/IAM/image/d04-047-06.jpg
#   inflating: iam-trocr/IAM/image/d04-047-07.jpg
#   inflating: iam-trocr/IAM/image/d04-047-08.jpg
#   inflating: iam-trocr/IAM/image/d04-050-00.jpg
#   inflating: iam-trocr/IAM/image/d04-050-01.jpg
#   inflating: iam-trocr/IAM/image/d04-050-02.jpg
#   inflating: iam-trocr/IAM/image/d04-050-03.jpg
#   inflating: iam-trocr/IAM/image/d04-050-04.jpg
#   inflating: iam-trocr/IAM/image/d04-050-05.jpg
#   inflating: iam-trocr/IAM/image/d04-053-00.jpg
#   inflating: iam-trocr/IAM/image/d04-053-01.jpg
#   inflating: iam-trocr/IAM/image/d04-053-02.jpg
#   inflating: iam-trocr/IAM/image/d04-053-03.jpg
#   inflating: iam-trocr/IAM/image/d04-053-04.jpg
#   inflating: iam-trocr/IAM/image/d04-053-05.jpg
#   inflating: iam-trocr/IAM/image/d04-053-06.jpg
#   inflating: iam-trocr/IAM/image/d04-053-07.jpg
#   inflating: iam-trocr/IAM/image/d04-053-08.jpg
#   inflating: iam-trocr/IAM/image/d04-053-09.jpg
#   inflating: iam-trocr/IAM/image/d04-053-10.jpg
#   inflating: iam-trocr/IAM/image/d04-058-00.jpg
#   inflating: iam-trocr/IAM/image/d04-058-01.jpg
#   inflating: iam-trocr/IAM/image/d04-058-02.jpg
#   inflating: iam-trocr/IAM/image/d04-058-03.jpg
#   inflating: iam-trocr/IAM/image/d04-058-04.jpg
#   inflating: iam-trocr/IAM/image/d04-058-05.jpg
#   inflating: iam-trocr/IAM/image/d04-058-06.jpg
#   inflating: iam-trocr/IAM/image/d04-062-00.jpg
#   inflating: iam-trocr/IAM/image/d04-062-01.jpg
#   inflating: iam-trocr/IAM/image/d04-062-02.jpg
#   inflating: iam-trocr/IAM/image/d04-062-03.jpg
#   inflating: iam-trocr/IAM/image/d04-062-04.jpg
#   inflating: iam-trocr/IAM/image/d04-066-00.jpg
#   inflating: iam-trocr/IAM/image/d04-066-01.jpg
#   inflating: iam-trocr/IAM/image/d04-066-02.jpg
#   inflating: iam-trocr/IAM/image/d04-066-03.jpg
#   inflating: iam-trocr/IAM/image/d04-066-04.jpg
#   inflating: iam-trocr/IAM/image/d04-066-05.jpg
#   inflating: iam-trocr/IAM/image/d04-066-06.jpg
#   inflating: iam-trocr/IAM/image/d04-066-07.jpg
#   inflating: iam-trocr/IAM/image/d04-066-08.jpg
#   inflating: iam-trocr/IAM/image/d04-066-09.jpg
#   inflating: iam-trocr/IAM/image/d04-086-00.jpg
#   inflating: iam-trocr/IAM/image/d04-086-01.jpg
#   inflating: iam-trocr/IAM/image/d04-086-02.jpg
#   inflating: iam-trocr/IAM/image/d04-086-03.jpg
#   inflating: iam-trocr/IAM/image/d04-086-04.jpg
#   inflating: iam-trocr/IAM/image/d04-086-05.jpg
#   inflating: iam-trocr/IAM/image/d04-086-06.jpg
#   inflating: iam-trocr/IAM/image/d04-089-00.jpg
#   inflating: iam-trocr/IAM/image/d04-089-01.jpg
#   inflating: iam-trocr/IAM/image/d04-089-02.jpg
#   inflating: iam-trocr/IAM/image/d04-089-03.jpg
#   inflating: iam-trocr/IAM/image/d04-089-04.jpg
#   inflating: iam-trocr/IAM/image/d04-089-05.jpg
#   inflating: iam-trocr/IAM/image/d04-089-06.jpg
#   inflating: iam-trocr/IAM/image/d04-089-07.jpg
#   inflating: iam-trocr/IAM/image/d04-096-00.jpg
#   inflating: iam-trocr/IAM/image/d04-096-01.jpg
#   inflating: iam-trocr/IAM/image/d04-096-02.jpg
#   inflating: iam-trocr/IAM/image/d04-096-03.jpg
#   inflating: iam-trocr/IAM/image/d04-096-04.jpg
#   inflating: iam-trocr/IAM/image/d04-096-05.jpg
#   inflating: iam-trocr/IAM/image/d04-096-06.jpg
#   inflating: iam-trocr/IAM/image/d04-096-07.jpg
#   inflating: iam-trocr/IAM/image/d04-101-00.jpg
#   inflating: iam-trocr/IAM/image/d04-101-01.jpg
#   inflating: iam-trocr/IAM/image/d04-101-02.jpg
#   inflating: iam-trocr/IAM/image/d04-101-03.jpg
#   inflating: iam-trocr/IAM/image/d04-101-04.jpg
#   inflating: iam-trocr/IAM/image/d04-101-05.jpg
#   inflating: iam-trocr/IAM/image/d04-111-00.jpg
#   inflating: iam-trocr/IAM/image/d04-111-01.jpg
#   inflating: iam-trocr/IAM/image/d04-111-02.jpg
#   inflating: iam-trocr/IAM/image/d04-111-03.jpg
#   inflating: iam-trocr/IAM/image/d04-111-04.jpg
#   inflating: iam-trocr/IAM/image/d04-111-05.jpg
#   inflating: iam-trocr/IAM/image/d04-111-06.jpg
#   inflating: iam-trocr/IAM/image/d04-111-07.jpg
#   inflating: iam-trocr/IAM/image/d04-111-08.jpg
#   inflating: iam-trocr/IAM/image/d04-111-09.jpg
#   inflating: iam-trocr/IAM/image/d04-111-10.jpg
#   inflating: iam-trocr/IAM/image/d04-111-11.jpg
#   inflating: iam-trocr/IAM/image/d04-125-00.jpg
#   inflating: iam-trocr/IAM/image/d04-125-01.jpg
#   inflating: iam-trocr/IAM/image/d04-125-02.jpg
#   inflating: iam-trocr/IAM/image/d04-125-03.jpg
#   inflating: iam-trocr/IAM/image/d04-125-04.jpg
#   inflating: iam-trocr/IAM/image/d04-125-05.jpg
#   inflating: iam-trocr/IAM/image/d04-131-00.jpg
#   inflating: iam-trocr/IAM/image/d04-131-01.jpg
#   inflating: iam-trocr/IAM/image/d04-131-02.jpg
#   inflating: iam-trocr/IAM/image/d04-131-03.jpg
#   inflating: iam-trocr/IAM/image/d04-131-04.jpg
#   inflating: iam-trocr/IAM/image/d04-131-05.jpg
#   inflating: iam-trocr/IAM/image/d04-131-06.jpg
#   inflating: iam-trocr/IAM/image/d05-008-00.jpg
#   inflating: iam-trocr/IAM/image/d05-008-01.jpg
#   inflating: iam-trocr/IAM/image/d05-008-02.jpg
#   inflating: iam-trocr/IAM/image/d05-008-03.jpg
#   inflating: iam-trocr/IAM/image/d05-008-04.jpg
#   inflating: iam-trocr/IAM/image/d05-008-05.jpg
#   inflating: iam-trocr/IAM/image/d05-008-06.jpg
#   inflating: iam-trocr/IAM/image/d05-008-07.jpg
#   inflating: iam-trocr/IAM/image/d05-013-00.jpg
#   inflating: iam-trocr/IAM/image/d05-013-01.jpg
#   inflating: iam-trocr/IAM/image/d05-013-02.jpg
#   inflating: iam-trocr/IAM/image/d05-013-03.jpg
#   inflating: iam-trocr/IAM/image/d05-013-04.jpg
#   inflating: iam-trocr/IAM/image/d05-013-05.jpg
#   inflating: iam-trocr/IAM/image/d05-013-06.jpg
#   inflating: iam-trocr/IAM/image/d05-013-07.jpg
#   inflating: iam-trocr/IAM/image/d05-013-08.jpg
#   inflating: iam-trocr/IAM/image/d05-021-00.jpg
#   inflating: iam-trocr/IAM/image/d05-021-01.jpg
#   inflating: iam-trocr/IAM/image/d05-021-02.jpg
#   inflating: iam-trocr/IAM/image/d05-021-03.jpg
#   inflating: iam-trocr/IAM/image/d05-021-04.jpg
#   inflating: iam-trocr/IAM/image/d05-021-05.jpg
#   inflating: iam-trocr/IAM/image/d05-021-06.jpg
#   inflating: iam-trocr/IAM/image/d05-021-07.jpg
#   inflating: iam-trocr/IAM/image/d05-021-08.jpg
#   inflating: iam-trocr/IAM/image/d05-025-00.jpg
#   inflating: iam-trocr/IAM/image/d05-025-01.jpg
#   inflating: iam-trocr/IAM/image/d05-025-02.jpg
#   inflating: iam-trocr/IAM/image/d05-025-03.jpg
#   inflating: iam-trocr/IAM/image/d05-025-04.jpg
#   inflating: iam-trocr/IAM/image/d05-025-05.jpg
#   inflating: iam-trocr/IAM/image/d05-025-06.jpg
#   inflating: iam-trocr/IAM/image/d05-025-07.jpg
#   inflating: iam-trocr/IAM/image/d05-025-08.jpg
#   inflating: iam-trocr/IAM/image/d05-025-09.jpg
#   inflating: iam-trocr/IAM/image/d05-030-00.jpg
#   inflating: iam-trocr/IAM/image/d05-030-01.jpg
#   inflating: iam-trocr/IAM/image/d05-030-02.jpg
#   inflating: iam-trocr/IAM/image/d05-030-03.jpg
#   inflating: iam-trocr/IAM/image/d05-030-04.jpg
#   inflating: iam-trocr/IAM/image/d05-030-05.jpg
#   inflating: iam-trocr/IAM/image/d05-030-06.jpg
#   inflating: iam-trocr/IAM/image/d05-030-07.jpg
#   inflating: iam-trocr/IAM/image/d05-030-08.jpg
#   inflating: iam-trocr/IAM/image/d05-040-00.jpg
#   inflating: iam-trocr/IAM/image/d05-040-01.jpg
#   inflating: iam-trocr/IAM/image/d05-040-02.jpg
#   inflating: iam-trocr/IAM/image/d05-040-03.jpg
#   inflating: iam-trocr/IAM/image/d05-040-04.jpg
#   inflating: iam-trocr/IAM/image/d05-040-05.jpg
#   inflating: iam-trocr/IAM/image/d06-003-00.jpg
#   inflating: iam-trocr/IAM/image/d06-003-01.jpg
#   inflating: iam-trocr/IAM/image/d06-003-02.jpg
#   inflating: iam-trocr/IAM/image/d06-003-03.jpg
#   inflating: iam-trocr/IAM/image/d06-003-04.jpg
#   inflating: iam-trocr/IAM/image/d06-003-05.jpg
#   inflating: iam-trocr/IAM/image/d06-003-06.jpg
#   inflating: iam-trocr/IAM/image/d06-008-00.jpg
#   inflating: iam-trocr/IAM/image/d06-008-01.jpg
#   inflating: iam-trocr/IAM/image/d06-008-02.jpg
#   inflating: iam-trocr/IAM/image/d06-008-03.jpg
#   inflating: iam-trocr/IAM/image/d06-008-04.jpg
#   inflating: iam-trocr/IAM/image/d06-008-05.jpg
#   inflating: iam-trocr/IAM/image/d06-008-06.jpg
#   inflating: iam-trocr/IAM/image/d06-008-07.jpg
#   inflating: iam-trocr/IAM/image/d06-008-08.jpg
#   inflating: iam-trocr/IAM/image/d06-008-09.jpg
#   inflating: iam-trocr/IAM/image/d06-011-00.jpg
#   inflating: iam-trocr/IAM/image/d06-011-01.jpg
#   inflating: iam-trocr/IAM/image/d06-011-02.jpg
#   inflating: iam-trocr/IAM/image/d06-011-03.jpg
#   inflating: iam-trocr/IAM/image/d06-011-04.jpg
#   inflating: iam-trocr/IAM/image/d06-011-05.jpg
#   inflating: iam-trocr/IAM/image/d06-011-06.jpg
#   inflating: iam-trocr/IAM/image/d06-011-07.jpg
#   inflating: iam-trocr/IAM/image/d06-011-08.jpg
#   inflating: iam-trocr/IAM/image/d06-011-09.jpg
#   inflating: iam-trocr/IAM/image/d06-020-00.jpg
#   inflating: iam-trocr/IAM/image/d06-020-01.jpg
#   inflating: iam-trocr/IAM/image/d06-020-02.jpg
#   inflating: iam-trocr/IAM/image/d06-020-03.jpg
#   inflating: iam-trocr/IAM/image/d06-020-04.jpg
#   inflating: iam-trocr/IAM/image/d06-020-05.jpg
#   inflating: iam-trocr/IAM/image/d06-020-06.jpg
#   inflating: iam-trocr/IAM/image/d06-020-07.jpg
#   inflating: iam-trocr/IAM/image/d06-020-08.jpg
#   inflating: iam-trocr/IAM/image/d06-020-09.jpg
#   inflating: iam-trocr/IAM/image/d06-025-00.jpg
#   inflating: iam-trocr/IAM/image/d06-025-01.jpg
#   inflating: iam-trocr/IAM/image/d06-025-02.jpg
#   inflating: iam-trocr/IAM/image/d06-025-03.jpg
#   inflating: iam-trocr/IAM/image/d06-025-04.jpg
#   inflating: iam-trocr/IAM/image/d06-025-05.jpg
#   inflating: iam-trocr/IAM/image/d06-025-06.jpg
#   inflating: iam-trocr/IAM/image/d06-025-07.jpg
#   inflating: iam-trocr/IAM/image/d06-027-00.jpg
#   inflating: iam-trocr/IAM/image/d06-027-01.jpg
#   inflating: iam-trocr/IAM/image/d06-027-02.jpg
#   inflating: iam-trocr/IAM/image/d06-027-03.jpg
#   inflating: iam-trocr/IAM/image/d06-027-04.jpg
#   inflating: iam-trocr/IAM/image/d06-027-05.jpg
#   inflating: iam-trocr/IAM/image/d06-027-06.jpg
#   inflating: iam-trocr/IAM/image/d06-027-07.jpg
#   inflating: iam-trocr/IAM/image/d06-037-00.jpg
#   inflating: iam-trocr/IAM/image/d06-037-01.jpg
#   inflating: iam-trocr/IAM/image/d06-037-02.jpg
#   inflating: iam-trocr/IAM/image/d06-037-03.jpg
#   inflating: iam-trocr/IAM/image/d06-037-04.jpg
#   inflating: iam-trocr/IAM/image/d06-037-05.jpg
#   inflating: iam-trocr/IAM/image/d06-037-06.jpg
#   inflating: iam-trocr/IAM/image/d06-037-07.jpg
#   inflating: iam-trocr/IAM/image/d06-041-00.jpg
#   inflating: iam-trocr/IAM/image/d06-041-01.jpg
#   inflating: iam-trocr/IAM/image/d06-041-02.jpg
#   inflating: iam-trocr/IAM/image/d06-041-03.jpg
#   inflating: iam-trocr/IAM/image/d06-041-04.jpg
#   inflating: iam-trocr/IAM/image/d06-041-05.jpg
#   inflating: iam-trocr/IAM/image/d06-041-06.jpg
#   inflating: iam-trocr/IAM/image/d06-041-07.jpg
#   inflating: iam-trocr/IAM/image/d06-046-00.jpg
#   inflating: iam-trocr/IAM/image/d06-046-01.jpg
#   inflating: iam-trocr/IAM/image/d06-046-02.jpg
#   inflating: iam-trocr/IAM/image/d06-046-03.jpg
#   inflating: iam-trocr/IAM/image/d06-046-04.jpg
#   inflating: iam-trocr/IAM/image/d06-046-05.jpg
#   inflating: iam-trocr/IAM/image/d06-046-06.jpg
#   inflating: iam-trocr/IAM/image/d06-046-07.jpg
#   inflating: iam-trocr/IAM/image/d06-046-08.jpg
#   inflating: iam-trocr/IAM/image/d06-046-09.jpg
#   inflating: iam-trocr/IAM/image/d06-056-00.jpg
#   inflating: iam-trocr/IAM/image/d06-056-01.jpg
#   inflating: iam-trocr/IAM/image/d06-056-02.jpg
#   inflating: iam-trocr/IAM/image/d06-056-03.jpg
#   inflating: iam-trocr/IAM/image/d06-056-04.jpg
#   inflating: iam-trocr/IAM/image/d06-056-05.jpg
#   inflating: iam-trocr/IAM/image/d06-056-06.jpg
#   inflating: iam-trocr/IAM/image/d06-056-07.jpg
#   inflating: iam-trocr/IAM/image/d06-056-08.jpg
#   inflating: iam-trocr/IAM/image/d06-060-00.jpg
#   inflating: iam-trocr/IAM/image/d06-060-01.jpg
#   inflating: iam-trocr/IAM/image/d06-060-02.jpg
#   inflating: iam-trocr/IAM/image/d06-060-03.jpg
#   inflating: iam-trocr/IAM/image/d06-060-04.jpg
#   inflating: iam-trocr/IAM/image/d06-060-05.jpg
#   inflating: iam-trocr/IAM/image/d06-060-06.jpg
#   inflating: iam-trocr/IAM/image/d06-060-07.jpg
#   inflating: iam-trocr/IAM/image/d06-060-08.jpg
#   inflating: iam-trocr/IAM/image/d06-060-09.jpg
#   inflating: iam-trocr/IAM/image/d06-063-00.jpg
#   inflating: iam-trocr/IAM/image/d06-063-01.jpg
#   inflating: iam-trocr/IAM/image/d06-063-02.jpg
#   inflating: iam-trocr/IAM/image/d06-063-03.jpg
#   inflating: iam-trocr/IAM/image/d06-063-04.jpg
#   inflating: iam-trocr/IAM/image/d06-063-05.jpg
#   inflating: iam-trocr/IAM/image/d06-063-06.jpg
#   inflating: iam-trocr/IAM/image/d06-063-07.jpg
#   inflating: iam-trocr/IAM/image/d06-063-08.jpg
#   inflating: iam-trocr/IAM/image/d06-063-09.jpg
#   inflating: iam-trocr/IAM/image/d06-063-10.jpg
#   inflating: iam-trocr/IAM/image/d06-067-00.jpg
#   inflating: iam-trocr/IAM/image/d06-067-01.jpg
#   inflating: iam-trocr/IAM/image/d06-067-02.jpg
#   inflating: iam-trocr/IAM/image/d06-067-03.jpg
#   inflating: iam-trocr/IAM/image/d06-067-04.jpg
#   inflating: iam-trocr/IAM/image/d06-067-05.jpg
#   inflating: iam-trocr/IAM/image/d06-067-06.jpg
#   inflating: iam-trocr/IAM/image/d06-067-07.jpg
#   inflating: iam-trocr/IAM/image/d06-067-08.jpg
#   inflating: iam-trocr/IAM/image/d06-067-09.jpg
#   inflating: iam-trocr/IAM/image/d06-072-00.jpg
#   inflating: iam-trocr/IAM/image/d06-072-01.jpg
#   inflating: iam-trocr/IAM/image/d06-072-02.jpg
#   inflating: iam-trocr/IAM/image/d06-072-03.jpg
#   inflating: iam-trocr/IAM/image/d06-072-04.jpg
#   inflating: iam-trocr/IAM/image/d06-072-05.jpg
#   inflating: iam-trocr/IAM/image/d06-072-06.jpg
#   inflating: iam-trocr/IAM/image/d06-072-07.jpg
#   inflating: iam-trocr/IAM/image/d06-072-08.jpg
#   inflating: iam-trocr/IAM/image/d06-072-09.jpg
#   inflating: iam-trocr/IAM/image/d06-072-10.jpg
#   inflating: iam-trocr/IAM/image/d06-076-00.jpg
#   inflating: iam-trocr/IAM/image/d06-076-01.jpg
#   inflating: iam-trocr/IAM/image/d06-076-02.jpg
#   inflating: iam-trocr/IAM/image/d06-076-03.jpg
#   inflating: iam-trocr/IAM/image/d06-076-04.jpg
#   inflating: iam-trocr/IAM/image/d06-076-05.jpg
#   inflating: iam-trocr/IAM/image/d06-086-00.jpg
#   inflating: iam-trocr/IAM/image/d06-086-01.jpg
#   inflating: iam-trocr/IAM/image/d06-086-02.jpg
#   inflating: iam-trocr/IAM/image/d06-086-03.jpg
#   inflating: iam-trocr/IAM/image/d06-086-04.jpg
#   inflating: iam-trocr/IAM/image/d06-086-05.jpg
#   inflating: iam-trocr/IAM/image/d06-086-06.jpg
#   inflating: iam-trocr/IAM/image/d06-086-07.jpg
#   inflating: iam-trocr/IAM/image/d06-086-08.jpg
#   inflating: iam-trocr/IAM/image/d06-086-09.jpg
#   inflating: iam-trocr/IAM/image/d06-086-10.jpg
#   inflating: iam-trocr/IAM/image/d06-096-00.jpg
#   inflating: iam-trocr/IAM/image/d06-096-01.jpg
#   inflating: iam-trocr/IAM/image/d06-096-02.jpg
#   inflating: iam-trocr/IAM/image/d06-096-03.jpg
#   inflating: iam-trocr/IAM/image/d06-096-04.jpg
#   inflating: iam-trocr/IAM/image/d06-096-05.jpg
#   inflating: iam-trocr/IAM/image/d06-096-06.jpg
#   inflating: iam-trocr/IAM/image/d06-096-07.jpg
#   inflating: iam-trocr/IAM/image/d06-096-08.jpg
#   inflating: iam-trocr/IAM/image/d06-100-00.jpg
#   inflating: iam-trocr/IAM/image/d06-100-01.jpg
#   inflating: iam-trocr/IAM/image/d06-100-02.jpg
#   inflating: iam-trocr/IAM/image/d06-100-03.jpg
#   inflating: iam-trocr/IAM/image/d06-100-04.jpg
#   inflating: iam-trocr/IAM/image/d06-100-05.jpg
#   inflating: iam-trocr/IAM/image/d06-100-06.jpg
#   inflating: iam-trocr/IAM/image/d06-100-07.jpg
#   inflating: iam-trocr/IAM/image/d06-104-00.jpg
#   inflating: iam-trocr/IAM/image/d06-104-01.jpg
#   inflating: iam-trocr/IAM/image/d06-104-02.jpg
#   inflating: iam-trocr/IAM/image/d06-104-03.jpg
#   inflating: iam-trocr/IAM/image/d06-104-04.jpg
#   inflating: iam-trocr/IAM/image/d06-104-05.jpg
#   inflating: iam-trocr/IAM/image/d06-104-06.jpg
#   inflating: iam-trocr/IAM/image/d06-104-07.jpg
#   inflating: iam-trocr/IAM/image/d06-104-08.jpg
#   inflating: iam-trocr/IAM/image/d06-104-09.jpg
#   inflating: iam-trocr/IAM/image/d06-104-10.jpg
#   inflating: iam-trocr/IAM/image/d06-107-00.jpg
#   inflating: iam-trocr/IAM/image/d06-107-01.jpg
#   inflating: iam-trocr/IAM/image/d06-107-02.jpg
#   inflating: iam-trocr/IAM/image/d06-107-03.jpg
#   inflating: iam-trocr/IAM/image/d06-107-04.jpg
#   inflating: iam-trocr/IAM/image/d06-107-05.jpg
#   inflating: iam-trocr/IAM/image/d06-107-06.jpg
#   inflating: iam-trocr/IAM/image/d06-107-07.jpg
#   inflating: iam-trocr/IAM/image/d06-107-08.jpg
#   inflating: iam-trocr/IAM/image/d06-107-09.jpg
#   inflating: iam-trocr/IAM/image/d06-107-10.jpg
#   inflating: iam-trocr/IAM/image/d06-111-00.jpg
#   inflating: iam-trocr/IAM/image/d06-111-01.jpg
#   inflating: iam-trocr/IAM/image/d06-111-02.jpg
#   inflating: iam-trocr/IAM/image/d06-111-03.jpg
#   inflating: iam-trocr/IAM/image/d06-111-04.jpg
#   inflating: iam-trocr/IAM/image/d06-111-05.jpg
#   inflating: iam-trocr/IAM/image/d06-111-06.jpg
#   inflating: iam-trocr/IAM/image/d06-113-00.jpg
#   inflating: iam-trocr/IAM/image/d06-113-01.jpg
#   inflating: iam-trocr/IAM/image/d06-113-02.jpg
#   inflating: iam-trocr/IAM/image/d06-113-03.jpg
#   inflating: iam-trocr/IAM/image/d06-113-04.jpg
#   inflating: iam-trocr/IAM/image/d07-082-00.jpg
#   inflating: iam-trocr/IAM/image/d07-082-01.jpg
#   inflating: iam-trocr/IAM/image/d07-082-02.jpg
#   inflating: iam-trocr/IAM/image/d07-082-03.jpg
#   inflating: iam-trocr/IAM/image/d07-082-04.jpg
#   inflating: iam-trocr/IAM/image/d07-082-05.jpg
#   inflating: iam-trocr/IAM/image/d07-082-06.jpg
#   inflating: iam-trocr/IAM/image/d07-082-07.jpg
#   inflating: iam-trocr/IAM/image/d07-082-08.jpg
#   inflating: iam-trocr/IAM/image/d07-085-00.jpg
#   inflating: iam-trocr/IAM/image/d07-085-01.jpg
#   inflating: iam-trocr/IAM/image/d07-085-02.jpg
#   inflating: iam-trocr/IAM/image/d07-085-03.jpg
#   inflating: iam-trocr/IAM/image/d07-085-04.jpg
#   inflating: iam-trocr/IAM/image/d07-085-05.jpg
#   inflating: iam-trocr/IAM/image/d07-085-06.jpg
#   inflating: iam-trocr/IAM/image/d07-085-07.jpg
#   inflating: iam-trocr/IAM/image/d07-089-00.jpg
#   inflating: iam-trocr/IAM/image/d07-089-01.jpg
#   inflating: iam-trocr/IAM/image/d07-089-02.jpg
#   inflating: iam-trocr/IAM/image/d07-089-03.jpg
#   inflating: iam-trocr/IAM/image/d07-089-04.jpg
#   inflating: iam-trocr/IAM/image/d07-089-05.jpg
#   inflating: iam-trocr/IAM/image/d07-089-06.jpg
#   inflating: iam-trocr/IAM/image/d07-089-07.jpg
#   inflating: iam-trocr/IAM/image/d07-089-08.jpg
#   inflating: iam-trocr/IAM/image/d07-089-09.jpg
#   inflating: iam-trocr/IAM/image/d07-089-10.jpg
#   inflating: iam-trocr/IAM/image/d07-093-00.jpg
#   inflating: iam-trocr/IAM/image/d07-093-01.jpg
#   inflating: iam-trocr/IAM/image/d07-093-02.jpg
#   inflating: iam-trocr/IAM/image/d07-093-03.jpg
#   inflating: iam-trocr/IAM/image/d07-093-04.jpg
#   inflating: iam-trocr/IAM/image/d07-093-05.jpg
#   inflating: iam-trocr/IAM/image/d07-093-06.jpg
#   inflating: iam-trocr/IAM/image/d07-093-07.jpg
#   inflating: iam-trocr/IAM/image/d07-093-08.jpg
#   inflating: iam-trocr/IAM/image/d07-096-00.jpg
#   inflating: iam-trocr/IAM/image/d07-096-01.jpg
#   inflating: iam-trocr/IAM/image/d07-096-02.jpg
#   inflating: iam-trocr/IAM/image/d07-096-03.jpg
#   inflating: iam-trocr/IAM/image/d07-096-04.jpg
#   inflating: iam-trocr/IAM/image/d07-096-05.jpg
#   inflating: iam-trocr/IAM/image/d07-096-06.jpg
#   inflating: iam-trocr/IAM/image/d07-096-07.jpg
#   inflating: iam-trocr/IAM/image/d07-096-08.jpg
#   inflating: iam-trocr/IAM/image/d07-096-09.jpg
#   inflating: iam-trocr/IAM/image/d07-100-00.jpg
#   inflating: iam-trocr/IAM/image/d07-100-01.jpg
#   inflating: iam-trocr/IAM/image/d07-100-02.jpg
#   inflating: iam-trocr/IAM/image/d07-100-03.jpg
#   inflating: iam-trocr/IAM/image/d07-100-04.jpg
#   inflating: iam-trocr/IAM/image/d07-100-05.jpg
#   inflating: iam-trocr/IAM/image/d07-100-06.jpg
#   inflating: iam-trocr/IAM/image/d07-100-07.jpg
#   inflating: iam-trocr/IAM/image/d07-100-08.jpg
#   inflating: iam-trocr/IAM/image/d07-100-09.jpg
#   inflating: iam-trocr/IAM/image/d07-102-00.jpg
#   inflating: iam-trocr/IAM/image/d07-102-01.jpg
#   inflating: iam-trocr/IAM/image/d07-102-02.jpg
#   inflating: iam-trocr/IAM/image/d07-102-03.jpg
#   inflating: iam-trocr/IAM/image/d07-102-04.jpg
#   inflating: iam-trocr/IAM/image/d07-102-05.jpg
#   inflating: iam-trocr/IAM/image/d07-102-06.jpg
#   inflating: iam-trocr/IAM/image/d07-102-07.jpg
#   inflating: iam-trocr/IAM/image/e01-055-00.jpg
#   inflating: iam-trocr/IAM/image/e01-055-01.jpg
#   inflating: iam-trocr/IAM/image/e01-055-02.jpg
#   inflating: iam-trocr/IAM/image/e01-055-03.jpg
#   inflating: iam-trocr/IAM/image/e01-055-04.jpg
#   inflating: iam-trocr/IAM/image/e01-055-05.jpg
#   inflating: iam-trocr/IAM/image/e01-055-06.jpg
#   inflating: iam-trocr/IAM/image/e01-055-07.jpg
#   inflating: iam-trocr/IAM/image/e01-055-08.jpg
#   inflating: iam-trocr/IAM/image/e01-055-09.jpg
#   inflating: iam-trocr/IAM/image/e06-000-00.jpg
#   inflating: iam-trocr/IAM/image/e06-000-01.jpg
#   inflating: iam-trocr/IAM/image/e06-000-02.jpg
#   inflating: iam-trocr/IAM/image/e06-000-03.jpg
#   inflating: iam-trocr/IAM/image/e06-000-04.jpg
#   inflating: iam-trocr/IAM/image/e06-000-05.jpg
#   inflating: iam-trocr/IAM/image/e06-000-06.jpg
#   inflating: iam-trocr/IAM/image/e06-000-07.jpg
#   inflating: iam-trocr/IAM/image/e06-003-00.jpg
#   inflating: iam-trocr/IAM/image/e06-003-01.jpg
#   inflating: iam-trocr/IAM/image/e06-003-02.jpg
#   inflating: iam-trocr/IAM/image/e06-003-03.jpg
#   inflating: iam-trocr/IAM/image/e06-003-04.jpg
#   inflating: iam-trocr/IAM/image/e06-003-05.jpg
#   inflating: iam-trocr/IAM/image/e06-003-06.jpg
#   inflating: iam-trocr/IAM/image/e06-003-07.jpg
#   inflating: iam-trocr/IAM/image/e06-003-08.jpg
#   inflating: iam-trocr/IAM/image/e06-003-09.jpg
#   inflating: iam-trocr/IAM/image/e06-003-10.jpg
#   inflating: iam-trocr/IAM/image/e06-010-00.jpg
#   inflating: iam-trocr/IAM/image/e06-010-01.jpg
#   inflating: iam-trocr/IAM/image/e06-010-02.jpg
#   inflating: iam-trocr/IAM/image/e06-010-03.jpg
#   inflating: iam-trocr/IAM/image/e06-010-04.jpg
#   inflating: iam-trocr/IAM/image/e06-010-05.jpg
#   inflating: iam-trocr/IAM/image/e06-010-06.jpg
#   inflating: iam-trocr/IAM/image/e06-010-07.jpg
#   inflating: iam-trocr/IAM/image/e06-015-00.jpg
#   inflating: iam-trocr/IAM/image/e06-015-01.jpg
#   inflating: iam-trocr/IAM/image/e06-015-02.jpg
#   inflating: iam-trocr/IAM/image/e06-015-03.jpg
#   inflating: iam-trocr/IAM/image/e06-015-04.jpg
#   inflating: iam-trocr/IAM/image/e06-015-05.jpg
#   inflating: iam-trocr/IAM/image/e06-015-06.jpg
#   inflating: iam-trocr/IAM/image/e06-015-07.jpg
#   inflating: iam-trocr/IAM/image/e06-015-08.jpg
#   inflating: iam-trocr/IAM/image/e06-015-09.jpg
#   inflating: iam-trocr/IAM/image/e06-021-00.jpg
#   inflating: iam-trocr/IAM/image/e06-021-01.jpg
#   inflating: iam-trocr/IAM/image/e06-021-02.jpg
#   inflating: iam-trocr/IAM/image/e06-021-03.jpg
#   inflating: iam-trocr/IAM/image/e06-021-04.jpg
#   inflating: iam-trocr/IAM/image/e06-021-05.jpg
#   inflating: iam-trocr/IAM/image/e06-021-06.jpg
#   inflating: iam-trocr/IAM/image/e06-021-07.jpg
#   inflating: iam-trocr/IAM/image/e06-021-08.jpg
#   inflating: iam-trocr/IAM/image/e06-021-09.jpg
#   inflating: iam-trocr/IAM/image/e06-021-10.jpg
#   inflating: iam-trocr/IAM/image/e06-026-00.jpg
#   inflating: iam-trocr/IAM/image/e06-026-01.jpg
#   inflating: iam-trocr/IAM/image/e06-026-02.jpg
#   inflating: iam-trocr/IAM/image/e06-026-03.jpg
#   inflating: iam-trocr/IAM/image/e06-026-04.jpg
#   inflating: iam-trocr/IAM/image/e06-026-05.jpg
#   inflating: iam-trocr/IAM/image/e06-026-06.jpg
#   inflating: iam-trocr/IAM/image/e06-026-07.jpg
#   inflating: iam-trocr/IAM/image/e06-026-08.jpg
#   inflating: iam-trocr/IAM/image/e06-026-09.jpg
#   inflating: iam-trocr/IAM/image/e06-030-00.jpg
#   inflating: iam-trocr/IAM/image/e06-030-01.jpg
#   inflating: iam-trocr/IAM/image/e06-030-02.jpg
#   inflating: iam-trocr/IAM/image/e06-030-03.jpg
#   inflating: iam-trocr/IAM/image/e06-030-04.jpg
#   inflating: iam-trocr/IAM/image/e06-030-05.jpg
#   inflating: iam-trocr/IAM/image/e06-030-06.jpg
#   inflating: iam-trocr/IAM/image/e06-030-07.jpg
#   inflating: iam-trocr/IAM/image/e06-030-08.jpg
#   inflating: iam-trocr/IAM/image/e06-030-09.jpg
#   inflating: iam-trocr/IAM/image/e06-030-10.jpg
#   inflating: iam-trocr/IAM/image/e06-033-00.jpg
#   inflating: iam-trocr/IAM/image/e06-033-01.jpg
#   inflating: iam-trocr/IAM/image/e06-033-02.jpg
#   inflating: iam-trocr/IAM/image/e06-033-03.jpg
#   inflating: iam-trocr/IAM/image/e06-033-04.jpg
#   inflating: iam-trocr/IAM/image/e06-033-05.jpg
#   inflating: iam-trocr/IAM/image/e06-033-06.jpg
#   inflating: iam-trocr/IAM/image/e06-033-07.jpg
#   inflating: iam-trocr/IAM/image/e06-033-08.jpg
#   inflating: iam-trocr/IAM/image/e06-033-09.jpg
#   inflating: iam-trocr/IAM/image/e06-046-00.jpg
#   inflating: iam-trocr/IAM/image/e06-046-01.jpg
#   inflating: iam-trocr/IAM/image/e06-046-02.jpg
#   inflating: iam-trocr/IAM/image/e06-046-03.jpg
#   inflating: iam-trocr/IAM/image/e06-046-04.jpg
#   inflating: iam-trocr/IAM/image/e06-046-05.jpg
#   inflating: iam-trocr/IAM/image/e06-049-00.jpg
#   inflating: iam-trocr/IAM/image/e06-049-01.jpg
#   inflating: iam-trocr/IAM/image/e06-049-02.jpg
#   inflating: iam-trocr/IAM/image/e06-049-03.jpg
#   inflating: iam-trocr/IAM/image/e06-049-04.jpg
#   inflating: iam-trocr/IAM/image/e06-049-05.jpg
#   inflating: iam-trocr/IAM/image/e06-049-06.jpg
#   inflating: iam-trocr/IAM/image/e06-049-07.jpg
#   inflating: iam-trocr/IAM/image/e06-049-08.jpg
#   inflating: iam-trocr/IAM/image/e06-049-09.jpg
#   inflating: iam-trocr/IAM/image/e06-053-00.jpg
#   inflating: iam-trocr/IAM/image/e06-053-01.jpg
#   inflating: iam-trocr/IAM/image/e06-053-02.jpg
#   inflating: iam-trocr/IAM/image/e06-053-03.jpg
#   inflating: iam-trocr/IAM/image/e06-053-04.jpg
#   inflating: iam-trocr/IAM/image/e06-053-05.jpg
#   inflating: iam-trocr/IAM/image/e06-053-06.jpg
#   inflating: iam-trocr/IAM/image/e06-053-07.jpg
#   inflating: iam-trocr/IAM/image/e06-053-08.jpg
#   inflating: iam-trocr/IAM/image/e06-070-00.jpg
#   inflating: iam-trocr/IAM/image/e06-070-01.jpg
#   inflating: iam-trocr/IAM/image/e06-070-02.jpg
#   inflating: iam-trocr/IAM/image/e06-070-03.jpg
#   inflating: iam-trocr/IAM/image/e06-070-04.jpg
#   inflating: iam-trocr/IAM/image/e06-070-05.jpg
#   inflating: iam-trocr/IAM/image/e06-070-06.jpg
#   inflating: iam-trocr/IAM/image/e06-070-07.jpg
#   inflating: iam-trocr/IAM/image/e06-070-08.jpg
#   inflating: iam-trocr/IAM/image/e06-070-09.jpg
#   inflating: iam-trocr/IAM/image/f04-032-00.jpg
#   inflating: iam-trocr/IAM/image/f04-032-01.jpg
#   inflating: iam-trocr/IAM/image/f04-032-02.jpg
#   inflating: iam-trocr/IAM/image/f04-032-03.jpg
#   inflating: iam-trocr/IAM/image/f04-032-04.jpg
#   inflating: iam-trocr/IAM/image/f04-032-05.jpg
#   inflating: iam-trocr/IAM/image/f04-032-06.jpg
#   inflating: iam-trocr/IAM/image/f04-032-07.jpg
#   inflating: iam-trocr/IAM/image/f04-032-08.jpg
#   inflating: iam-trocr/IAM/image/f04-032-09.jpg
#   inflating: iam-trocr/IAM/image/f04-035-00.jpg
#   inflating: iam-trocr/IAM/image/f04-035-01.jpg
#   inflating: iam-trocr/IAM/image/f04-035-02.jpg
#   inflating: iam-trocr/IAM/image/f04-035-03.jpg
#   inflating: iam-trocr/IAM/image/f04-035-04.jpg
#   inflating: iam-trocr/IAM/image/f04-035-05.jpg
#   inflating: iam-trocr/IAM/image/f04-039-00.jpg
#   inflating: iam-trocr/IAM/image/f04-039-01.jpg
#   inflating: iam-trocr/IAM/image/f04-039-02.jpg
#   inflating: iam-trocr/IAM/image/f04-039-03.jpg
#   inflating: iam-trocr/IAM/image/f04-039-04.jpg
#   inflating: iam-trocr/IAM/image/f04-039-05.jpg
#   inflating: iam-trocr/IAM/image/f04-039-06.jpg
#   inflating: iam-trocr/IAM/image/f04-039-07.jpg
#   inflating: iam-trocr/IAM/image/f04-039-08.jpg
#   inflating: iam-trocr/IAM/image/f04-043-00.jpg
#   inflating: iam-trocr/IAM/image/f04-043-01.jpg
#   inflating: iam-trocr/IAM/image/f04-043-02.jpg
#   inflating: iam-trocr/IAM/image/f04-043-03.jpg
#   inflating: iam-trocr/IAM/image/f04-043-04.jpg
#   inflating: iam-trocr/IAM/image/f04-043-05.jpg
#   inflating: iam-trocr/IAM/image/f04-043-06.jpg
#   inflating: iam-trocr/IAM/image/f04-043-07.jpg
#   inflating: iam-trocr/IAM/image/f04-053-00.jpg
#   inflating: iam-trocr/IAM/image/f04-053-01.jpg
#   inflating: iam-trocr/IAM/image/f04-053-02.jpg
#   inflating: iam-trocr/IAM/image/f04-053-03.jpg
#   inflating: iam-trocr/IAM/image/f04-053-04.jpg
#   inflating: iam-trocr/IAM/image/f04-053-05.jpg
#   inflating: iam-trocr/IAM/image/f04-053-06.jpg
#   inflating: iam-trocr/IAM/image/f04-057-00.jpg
#   inflating: iam-trocr/IAM/image/f04-057-01.jpg
#   inflating: iam-trocr/IAM/image/f04-057-02.jpg
#   inflating: iam-trocr/IAM/image/f04-057-03.jpg
#   inflating: iam-trocr/IAM/image/f04-057-04.jpg
#   inflating: iam-trocr/IAM/image/f04-057-05.jpg
#   inflating: iam-trocr/IAM/image/f04-057-06.jpg
#   inflating: iam-trocr/IAM/image/f04-057-07.jpg
#   inflating: iam-trocr/IAM/image/f04-057-08.jpg
#   inflating: iam-trocr/IAM/image/f04-057-09.jpg
#   inflating: iam-trocr/IAM/image/f04-061-00.jpg
#   inflating: iam-trocr/IAM/image/f04-061-01.jpg
#   inflating: iam-trocr/IAM/image/f04-061-02.jpg
#   inflating: iam-trocr/IAM/image/f04-061-03.jpg
#   inflating: iam-trocr/IAM/image/f04-061-04.jpg
#   inflating: iam-trocr/IAM/image/f04-061-05.jpg
#   inflating: iam-trocr/IAM/image/f04-061-06.jpg
#   inflating: iam-trocr/IAM/image/f04-061-07.jpg
#   inflating: iam-trocr/IAM/image/f04-064-00.jpg
#   inflating: iam-trocr/IAM/image/f04-064-01.jpg
#   inflating: iam-trocr/IAM/image/f04-064-02.jpg
#   inflating: iam-trocr/IAM/image/f04-064-03.jpg
#   inflating: iam-trocr/IAM/image/f04-064-04.jpg
#   inflating: iam-trocr/IAM/image/f04-064-05.jpg
#   inflating: iam-trocr/IAM/image/f04-064-06.jpg
#   inflating: iam-trocr/IAM/image/f04-064-07.jpg
#   inflating: iam-trocr/IAM/image/f04-064-08.jpg
#   inflating: iam-trocr/IAM/image/f04-068-00.jpg
#   inflating: iam-trocr/IAM/image/f04-068-01.jpg
#   inflating: iam-trocr/IAM/image/f04-068-02.jpg
#   inflating: iam-trocr/IAM/image/f04-068-03.jpg
#   inflating: iam-trocr/IAM/image/f04-068-04.jpg
#   inflating: iam-trocr/IAM/image/f04-068-05.jpg
#   inflating: iam-trocr/IAM/image/f04-068-06.jpg
#   inflating: iam-trocr/IAM/image/f04-068-07.jpg
#   inflating: iam-trocr/IAM/image/f04-071-00.jpg
#   inflating: iam-trocr/IAM/image/f04-071-01.jpg
#   inflating: iam-trocr/IAM/image/f04-071-02.jpg
#   inflating: iam-trocr/IAM/image/f04-071-03.jpg
#   inflating: iam-trocr/IAM/image/f04-071-04.jpg
#   inflating: iam-trocr/IAM/image/f04-071-05.jpg
#   inflating: iam-trocr/IAM/image/f04-071-06.jpg
#   inflating: iam-trocr/IAM/image/f04-071-07.jpg
#   inflating: iam-trocr/IAM/image/f04-071-08.jpg
#   inflating: iam-trocr/IAM/image/f04-071-09.jpg
#   inflating: iam-trocr/IAM/image/f04-074-00.jpg
#   inflating: iam-trocr/IAM/image/f04-074-01.jpg
#   inflating: iam-trocr/IAM/image/f04-074-02.jpg
#   inflating: iam-trocr/IAM/image/f04-074-03.jpg
#   inflating: iam-trocr/IAM/image/f04-074-04.jpg
#   inflating: iam-trocr/IAM/image/f04-074-05.jpg
#   inflating: iam-trocr/IAM/image/f04-074-06.jpg
#   inflating: iam-trocr/IAM/image/f04-074-07.jpg
#   inflating: iam-trocr/IAM/image/f04-074-08.jpg
#   inflating: iam-trocr/IAM/image/f04-074-09.jpg
#   inflating: iam-trocr/IAM/image/f04-074-10.jpg
#   inflating: iam-trocr/IAM/image/f04-074-11.jpg
#   inflating: iam-trocr/IAM/image/f04-079-00.jpg
#   inflating: iam-trocr/IAM/image/f04-079-01.jpg
#   inflating: iam-trocr/IAM/image/f04-079-02.jpg
#   inflating: iam-trocr/IAM/image/f04-079-03.jpg
#   inflating: iam-trocr/IAM/image/f04-079-04.jpg
#   inflating: iam-trocr/IAM/image/f04-079-05.jpg
#   inflating: iam-trocr/IAM/image/f04-079-06.jpg
#   inflating: iam-trocr/IAM/image/f04-079-07.jpg
#   inflating: iam-trocr/IAM/image/f04-079-08.jpg
#   inflating: iam-trocr/IAM/image/f04-079-09.jpg
#   inflating: iam-trocr/IAM/image/f04-079-10.jpg
#   inflating: iam-trocr/IAM/image/f04-083-00.jpg
#   inflating: iam-trocr/IAM/image/f04-083-01.jpg
#   inflating: iam-trocr/IAM/image/f04-083-02.jpg
#   inflating: iam-trocr/IAM/image/f04-083-03.jpg
#   inflating: iam-trocr/IAM/image/f04-083-04.jpg
#   inflating: iam-trocr/IAM/image/f04-083-05.jpg
#   inflating: iam-trocr/IAM/image/f04-083-06.jpg
#   inflating: iam-trocr/IAM/image/f04-083-07.jpg
#   inflating: iam-trocr/IAM/image/f04-083-08.jpg
#   inflating: iam-trocr/IAM/image/f04-083-09.jpg
#   inflating: iam-trocr/IAM/image/f04-087-00.jpg
#   inflating: iam-trocr/IAM/image/f04-087-01.jpg
#   inflating: iam-trocr/IAM/image/f04-087-02.jpg
#   inflating: iam-trocr/IAM/image/f04-087-03.jpg
#   inflating: iam-trocr/IAM/image/f04-087-04.jpg
#   inflating: iam-trocr/IAM/image/f04-087-05.jpg
#   inflating: iam-trocr/IAM/image/f07-000-00.jpg
#   inflating: iam-trocr/IAM/image/f07-000-01.jpg
#   inflating: iam-trocr/IAM/image/f07-000-02.jpg
#   inflating: iam-trocr/IAM/image/f07-000-03.jpg
#   inflating: iam-trocr/IAM/image/f07-000-04.jpg
#   inflating: iam-trocr/IAM/image/f07-000-05.jpg
#   inflating: iam-trocr/IAM/image/f07-000-06.jpg
#   inflating: iam-trocr/IAM/image/f07-000-07.jpg
#   inflating: iam-trocr/IAM/image/f07-000-08.jpg
#   inflating: iam-trocr/IAM/image/f07-000b-00.jpg
#   inflating: iam-trocr/IAM/image/f07-000b-01.jpg
#   inflating: iam-trocr/IAM/image/f07-000b-02.jpg
#   inflating: iam-trocr/IAM/image/f07-000b-03.jpg
#   inflating: iam-trocr/IAM/image/f07-000b-04.jpg
#   inflating: iam-trocr/IAM/image/f07-000b-05.jpg
#   inflating: iam-trocr/IAM/image/f07-000b-06.jpg
#   inflating: iam-trocr/IAM/image/f07-002-00.jpg
#   inflating: iam-trocr/IAM/image/f07-002-01.jpg
#   inflating: iam-trocr/IAM/image/f07-002-02.jpg
#   inflating: iam-trocr/IAM/image/f07-002-03.jpg
#   inflating: iam-trocr/IAM/image/f07-002-04.jpg
#   inflating: iam-trocr/IAM/image/f07-002-05.jpg
#   inflating: iam-trocr/IAM/image/f07-002-06.jpg
#   inflating: iam-trocr/IAM/image/f07-002-07.jpg
#   inflating: iam-trocr/IAM/image/f07-002-08.jpg
#   inflating: iam-trocr/IAM/image/f07-006-00.jpg
#   inflating: iam-trocr/IAM/image/f07-006-01.jpg
#   inflating: iam-trocr/IAM/image/f07-006-02.jpg
#   inflating: iam-trocr/IAM/image/f07-006-03.jpg
#   inflating: iam-trocr/IAM/image/f07-006-04.jpg
#   inflating: iam-trocr/IAM/image/f07-006-05.jpg
#   inflating: iam-trocr/IAM/image/f07-006-06.jpg
#   inflating: iam-trocr/IAM/image/f07-009-00.jpg
#   inflating: iam-trocr/IAM/image/f07-009-01.jpg
#   inflating: iam-trocr/IAM/image/f07-009-02.jpg
#   inflating: iam-trocr/IAM/image/f07-009-03.jpg
#   inflating: iam-trocr/IAM/image/f07-009-04.jpg
#   inflating: iam-trocr/IAM/image/f07-009-05.jpg
#   inflating: iam-trocr/IAM/image/f07-009-06.jpg
#   inflating: iam-trocr/IAM/image/f07-009-07.jpg
#   inflating: iam-trocr/IAM/image/f07-009-08.jpg
#   inflating: iam-trocr/IAM/image/f07-009-09.jpg
#   inflating: iam-trocr/IAM/image/f07-013-00.jpg
#   inflating: iam-trocr/IAM/image/f07-013-01.jpg
#   inflating: iam-trocr/IAM/image/f07-013-02.jpg
#   inflating: iam-trocr/IAM/image/f07-013-03.jpg
#   inflating: iam-trocr/IAM/image/f07-013-04.jpg
#   inflating: iam-trocr/IAM/image/f07-013-05.jpg
#   inflating: iam-trocr/IAM/image/f07-013-06.jpg
#   inflating: iam-trocr/IAM/image/f07-013-07.jpg
#   inflating: iam-trocr/IAM/image/f07-013-08.jpg
#   inflating: iam-trocr/IAM/image/f07-013-09.jpg
#   inflating: iam-trocr/IAM/image/f07-013-10.jpg
#   inflating: iam-trocr/IAM/image/f07-016-00.jpg
#   inflating: iam-trocr/IAM/image/f07-016-01.jpg
#   inflating: iam-trocr/IAM/image/f07-016-02.jpg
#   inflating: iam-trocr/IAM/image/f07-016-03.jpg
#   inflating: iam-trocr/IAM/image/f07-016-04.jpg
#   inflating: iam-trocr/IAM/image/f07-016-05.jpg
#   inflating: iam-trocr/IAM/image/f07-016-06.jpg
#   inflating: iam-trocr/IAM/image/f07-016-07.jpg
#   inflating: iam-trocr/IAM/image/f07-016-08.jpg
#   inflating: iam-trocr/IAM/image/f07-016-09.jpg
#   inflating: iam-trocr/IAM/image/f07-016-10.jpg
#   inflating: iam-trocr/IAM/image/f07-019a-00.jpg
#   inflating: iam-trocr/IAM/image/f07-019a-01.jpg
#   inflating: iam-trocr/IAM/image/f07-019a-02.jpg
#   inflating: iam-trocr/IAM/image/f07-019a-03.jpg
#   inflating: iam-trocr/IAM/image/f07-019a-04.jpg
#   inflating: iam-trocr/IAM/image/f07-019a-05.jpg
#   inflating: iam-trocr/IAM/image/f07-019a-06.jpg
#   inflating: iam-trocr/IAM/image/f07-019a-07.jpg
#   inflating: iam-trocr/IAM/image/f07-019a-08.jpg
#   inflating: iam-trocr/IAM/image/f07-019b-00.jpg
#   inflating: iam-trocr/IAM/image/f07-019b-01.jpg
#   inflating: iam-trocr/IAM/image/f07-019b-02.jpg
#   inflating: iam-trocr/IAM/image/f07-019b-03.jpg
#   inflating: iam-trocr/IAM/image/f07-019b-04.jpg
#   inflating: iam-trocr/IAM/image/f07-019b-05.jpg
#   inflating: iam-trocr/IAM/image/f07-019b-06.jpg
#   inflating: iam-trocr/IAM/image/f07-019b-07.jpg
#   inflating: iam-trocr/IAM/image/f07-019b-08.jpg
#   inflating: iam-trocr/IAM/image/f07-019b-09.jpg
#   inflating: iam-trocr/IAM/image/f07-019b-10.jpg
#   inflating: iam-trocr/IAM/image/f07-021a-00.jpg
#   inflating: iam-trocr/IAM/image/f07-021a-01.jpg
#   inflating: iam-trocr/IAM/image/f07-021a-02.jpg
#   inflating: iam-trocr/IAM/image/f07-021a-03.jpg
#   inflating: iam-trocr/IAM/image/f07-021a-04.jpg
# ...
#   inflating: iam-trocr/IAM/image/p02-027-03.jpg
#   inflating: iam-trocr/IAM/image/p02-027-04.jpg
#   inflating: iam-trocr/IAM/image/p02-069-00.jpg
#   inflating: iam-trocr/IAM/image/p02-069-01.jpg
#   inflating: iam-trocr/IAM/image/p02-069-02.jpg
#   inflating: iam-trocr/IAM/image/p02-069-03.jpg
#   inflating: iam-trocr/IAM/image/p02-069-04.jpg
#   inflating: iam-trocr/IAM/image/p02-069-05.jpg
#   inflating: iam-trocr/IAM/image/p02-069-06.jpg
#   inflating: iam-trocr/IAM/image/p02-069-07.jpg
#   inflating: iam-trocr/IAM/image/p02-069-08.jpg
#   inflating: iam-trocr/IAM/image/p02-069-09.jpg
#   inflating: iam-trocr/IAM/image/p02-076-00.jpg
#   inflating: iam-trocr/IAM/image/p02-076-01.jpg
#   inflating: iam-trocr/IAM/image/p02-076-02.jpg
#   inflating: iam-trocr/IAM/image/p02-076-03.jpg
#   inflating: iam-trocr/IAM/image/p02-076-04.jpg
#   inflating: iam-trocr/IAM/image/p02-076-05.jpg
#   inflating: iam-trocr/IAM/image/p02-076-06.jpg
#   inflating: iam-trocr/IAM/image/p02-076-07.jpg
#   inflating: iam-trocr/IAM/image/p02-076-08.jpg
#   inflating: iam-trocr/IAM/image/p02-076-09.jpg
#   inflating: iam-trocr/IAM/image/p02-076-10.jpg
#   inflating: iam-trocr/IAM/image/p02-081-00.jpg
#   inflating: iam-trocr/IAM/image/p02-081-01.jpg
#   inflating: iam-trocr/IAM/image/p02-081-02.jpg
#   inflating: iam-trocr/IAM/image/p02-081-03.jpg
#   inflating: iam-trocr/IAM/image/p02-081-04.jpg
#   inflating: iam-trocr/IAM/image/p02-081-05.jpg
#   inflating: iam-trocr/IAM/image/p02-081-06.jpg
#   inflating: iam-trocr/IAM/image/p02-081-07.jpg
#   inflating: iam-trocr/IAM/image/p02-081-08.jpg
#   inflating: iam-trocr/IAM/image/p02-081-09.jpg
#   inflating: iam-trocr/IAM/image/p02-090-00.jpg
#   inflating: iam-trocr/IAM/image/p02-090-01.jpg
#   inflating: iam-trocr/IAM/image/p02-090-02.jpg
#   inflating: iam-trocr/IAM/image/p02-090-03.jpg
#   inflating: iam-trocr/IAM/image/p02-090-04.jpg
#   inflating: iam-trocr/IAM/image/p02-090-05.jpg
#   inflating: iam-trocr/IAM/image/p02-090-06.jpg
#   inflating: iam-trocr/IAM/image/p02-090-07.jpg
#   inflating: iam-trocr/IAM/image/p02-090-08.jpg
#   inflating: iam-trocr/IAM/image/p02-101-00.jpg
#   inflating: iam-trocr/IAM/image/p02-101-01.jpg
#   inflating: iam-trocr/IAM/image/p02-101-02.jpg
#   inflating: iam-trocr/IAM/image/p02-101-03.jpg
#   inflating: iam-trocr/IAM/image/p02-101-04.jpg
#   inflating: iam-trocr/IAM/image/p02-101-05.jpg
#   inflating: iam-trocr/IAM/image/p02-101-06.jpg
#   inflating: iam-trocr/IAM/image/p02-101-07.jpg
#   inflating: iam-trocr/IAM/image/p02-105-00.jpg
#   inflating: iam-trocr/IAM/image/p02-105-01.jpg
#   inflating: iam-trocr/IAM/image/p02-105-02.jpg
#   inflating: iam-trocr/IAM/image/p02-105-03.jpg
#   inflating: iam-trocr/IAM/image/p02-105-04.jpg
#   inflating: iam-trocr/IAM/image/p02-105-05.jpg
#   inflating: iam-trocr/IAM/image/p02-105-06.jpg
#   inflating: iam-trocr/IAM/image/p02-105-07.jpg
#   inflating: iam-trocr/IAM/image/p02-109-00.jpg
#   inflating: iam-trocr/IAM/image/p02-109-01.jpg
#   inflating: iam-trocr/IAM/image/p02-109-02.jpg
#   inflating: iam-trocr/IAM/image/p02-109-03.jpg
#   inflating: iam-trocr/IAM/image/p02-109-04.jpg
#   inflating: iam-trocr/IAM/image/p02-109-05.jpg
#   inflating: iam-trocr/IAM/image/p02-109-06.jpg
#   inflating: iam-trocr/IAM/image/p02-109-07.jpg
#   inflating: iam-trocr/IAM/image/p02-109-08.jpg
#   inflating: iam-trocr/IAM/image/p02-115-00.jpg
#   inflating: iam-trocr/IAM/image/p02-115-01.jpg
#   inflating: iam-trocr/IAM/image/p02-115-02.jpg
#   inflating: iam-trocr/IAM/image/p02-115-03.jpg
#   inflating: iam-trocr/IAM/image/p02-115-04.jpg
#   inflating: iam-trocr/IAM/image/p02-115-05.jpg
#   inflating: iam-trocr/IAM/image/p02-115-06.jpg
#   inflating: iam-trocr/IAM/image/p02-115-07.jpg
#   inflating: iam-trocr/IAM/image/p02-115-08.jpg
#   inflating: iam-trocr/IAM/image/p02-135-00.jpg
#   inflating: iam-trocr/IAM/image/p02-135-01.jpg
#   inflating: iam-trocr/IAM/image/p02-135-02.jpg
#   inflating: iam-trocr/IAM/image/p02-135-03.jpg
#   inflating: iam-trocr/IAM/image/p02-135-04.jpg
#   inflating: iam-trocr/IAM/image/p02-135-05.jpg
#   inflating: iam-trocr/IAM/image/p02-135-06.jpg
#   inflating: iam-trocr/IAM/image/p02-135-07.jpg
#   inflating: iam-trocr/IAM/image/p02-135-08.jpg
#   inflating: iam-trocr/IAM/image/p02-139-00.jpg
#   inflating: iam-trocr/IAM/image/p02-139-01.jpg
#   inflating: iam-trocr/IAM/image/p02-139-02.jpg
#   inflating: iam-trocr/IAM/image/p02-139-03.jpg
#   inflating: iam-trocr/IAM/image/p02-139-04.jpg
#   inflating: iam-trocr/IAM/image/p02-139-05.jpg
#   inflating: iam-trocr/IAM/image/p02-144-00.jpg
#   inflating: iam-trocr/IAM/image/p02-144-01.jpg
#   inflating: iam-trocr/IAM/image/p02-144-02.jpg
#   inflating: iam-trocr/IAM/image/p02-144-03.jpg
#   inflating: iam-trocr/IAM/image/p02-144-04.jpg
#   inflating: iam-trocr/IAM/image/p02-144-05.jpg
#   inflating: iam-trocr/IAM/image/p02-144-06.jpg
#   inflating: iam-trocr/IAM/image/p02-144-07.jpg
#   inflating: iam-trocr/IAM/image/p02-144-08.jpg
#   inflating: iam-trocr/IAM/image/p02-144-09.jpg
#   inflating: iam-trocr/IAM/image/p02-144-10.jpg
#   inflating: iam-trocr/IAM/image/p02-144-11.jpg
#   inflating: iam-trocr/IAM/image/p02-150-00.jpg
#   inflating: iam-trocr/IAM/image/p02-150-01.jpg
#   inflating: iam-trocr/IAM/image/p02-150-02.jpg
#   inflating: iam-trocr/IAM/image/p02-150-03.jpg
#   inflating: iam-trocr/IAM/image/p02-150-04.jpg
#   inflating: iam-trocr/IAM/image/p02-150-05.jpg
#   inflating: iam-trocr/IAM/image/p02-150-06.jpg
#   inflating: iam-trocr/IAM/image/p02-150-07.jpg
#   inflating: iam-trocr/IAM/image/p02-150-08.jpg
#   inflating: iam-trocr/IAM/image/p03-012-00.jpg
#   inflating: iam-trocr/IAM/image/p03-012-01.jpg
#   inflating: iam-trocr/IAM/image/p03-012-02.jpg
#   inflating: iam-trocr/IAM/image/p03-012-03.jpg
#   inflating: iam-trocr/IAM/image/p03-012-04.jpg
#   inflating: iam-trocr/IAM/image/p03-012-05.jpg
#   inflating: iam-trocr/IAM/image/p03-012-06.jpg
#   inflating: iam-trocr/IAM/image/p03-012-07.jpg
#   inflating: iam-trocr/IAM/image/p03-012-08.jpg
#   inflating: iam-trocr/IAM/image/p03-012-09.jpg
#   inflating: iam-trocr/IAM/image/p03-023-00.jpg
#   inflating: iam-trocr/IAM/image/p03-023-01.jpg
#   inflating: iam-trocr/IAM/image/p03-023-02.jpg
#   inflating: iam-trocr/IAM/image/p03-023-03.jpg
#   inflating: iam-trocr/IAM/image/p03-023-04.jpg
#   inflating: iam-trocr/IAM/image/p03-023-05.jpg
#   inflating: iam-trocr/IAM/image/p03-027-00.jpg
#   inflating: iam-trocr/IAM/image/p03-027-01.jpg
#   inflating: iam-trocr/IAM/image/p03-027-02.jpg
#   inflating: iam-trocr/IAM/image/p03-027-03.jpg
#   inflating: iam-trocr/IAM/image/p03-027-04.jpg
#   inflating: iam-trocr/IAM/image/p03-027-05.jpg
#   inflating: iam-trocr/IAM/image/p03-027-06.jpg
#   inflating: iam-trocr/IAM/image/p03-027-07.jpg
#   inflating: iam-trocr/IAM/image/p03-029-00.jpg
#   inflating: iam-trocr/IAM/image/p03-029-01.jpg
#   inflating: iam-trocr/IAM/image/p03-029-02.jpg
#   inflating: iam-trocr/IAM/image/p03-029-03.jpg
#   inflating: iam-trocr/IAM/image/p03-029-04.jpg
#   inflating: iam-trocr/IAM/image/p03-029-05.jpg
#   inflating: iam-trocr/IAM/image/p03-029-06.jpg
#   inflating: iam-trocr/IAM/image/p03-029-07.jpg
#   inflating: iam-trocr/IAM/image/p03-029-08.jpg
#   inflating: iam-trocr/IAM/image/p03-029-09.jpg
#   inflating: iam-trocr/IAM/image/p03-033-00.jpg
#   inflating: iam-trocr/IAM/image/p03-033-01.jpg
#   inflating: iam-trocr/IAM/image/p03-033-02.jpg
#   inflating: iam-trocr/IAM/image/p03-033-03.jpg
#   inflating: iam-trocr/IAM/image/p03-033-04.jpg
#   inflating: iam-trocr/IAM/image/p03-033-05.jpg
#   inflating: iam-trocr/IAM/image/p03-040-00.jpg
#   inflating: iam-trocr/IAM/image/p03-040-01.jpg
#   inflating: iam-trocr/IAM/image/p03-040-02.jpg
#   inflating: iam-trocr/IAM/image/p03-040-03.jpg
#   inflating: iam-trocr/IAM/image/p03-040-04.jpg
#   inflating: iam-trocr/IAM/image/p03-040-05.jpg
#   inflating: iam-trocr/IAM/image/p03-040-06.jpg
#   inflating: iam-trocr/IAM/image/p03-040-07.jpg
#   inflating: iam-trocr/IAM/image/p03-040-08.jpg
#   inflating: iam-trocr/IAM/image/p03-047-00.jpg
#   inflating: iam-trocr/IAM/image/p03-047-01.jpg
#   inflating: iam-trocr/IAM/image/p03-047-02.jpg
#   inflating: iam-trocr/IAM/image/p03-047-03.jpg
#   inflating: iam-trocr/IAM/image/p03-047-04.jpg
#   inflating: iam-trocr/IAM/image/p03-047-05.jpg
#   inflating: iam-trocr/IAM/image/p03-047-06.jpg
#   inflating: iam-trocr/IAM/image/p03-047-07.jpg
#   inflating: iam-trocr/IAM/image/p03-047-08.jpg
#   inflating: iam-trocr/IAM/image/p03-047-09.jpg
#   inflating: iam-trocr/IAM/image/p03-072-00.jpg
#   inflating: iam-trocr/IAM/image/p03-072-01.jpg
#   inflating: iam-trocr/IAM/image/p03-072-02.jpg
#   inflating: iam-trocr/IAM/image/p03-072-03.jpg
#   inflating: iam-trocr/IAM/image/p03-072-04.jpg
#   inflating: iam-trocr/IAM/image/p03-072-05.jpg
#   inflating: iam-trocr/IAM/image/p03-072-06.jpg
#   inflating: iam-trocr/IAM/image/p03-072-07.jpg
#   inflating: iam-trocr/IAM/image/p03-080-00.jpg
#   inflating: iam-trocr/IAM/image/p03-080-01.jpg
#   inflating: iam-trocr/IAM/image/p03-080-02.jpg
#   inflating: iam-trocr/IAM/image/p03-080-03.jpg
#   inflating: iam-trocr/IAM/image/p03-080-04.jpg
#   inflating: iam-trocr/IAM/image/p03-080-05.jpg
#   inflating: iam-trocr/IAM/image/p03-080-06.jpg
#   inflating: iam-trocr/IAM/image/p03-163-00.jpg
#   inflating: iam-trocr/IAM/image/p03-163-01.jpg
#   inflating: iam-trocr/IAM/image/p03-163-02.jpg
#   inflating: iam-trocr/IAM/image/p03-163-03.jpg
#   inflating: iam-trocr/IAM/image/p03-163-04.jpg
#   inflating: iam-trocr/IAM/image/p03-163-05.jpg
#   inflating: iam-trocr/IAM/image/p03-163-06.jpg
#   inflating: iam-trocr/IAM/image/p03-163-07.jpg
#   inflating: iam-trocr/IAM/image/p03-173-00.jpg
#   inflating: iam-trocr/IAM/image/p03-173-01.jpg
#   inflating: iam-trocr/IAM/image/p03-173-02.jpg
#   inflating: iam-trocr/IAM/image/p03-173-03.jpg
#   inflating: iam-trocr/IAM/image/p03-173-04.jpg
#   inflating: iam-trocr/IAM/image/p03-173-05.jpg
#   inflating: iam-trocr/IAM/image/p03-173-06.jpg
#   inflating: iam-trocr/IAM/image/p03-173-07.jpg
#   inflating: iam-trocr/IAM/image/p03-173-08.jpg
#   inflating: iam-trocr/IAM/image/p03-181-00.jpg
#   inflating: iam-trocr/IAM/image/p03-181-01.jpg
#   inflating: iam-trocr/IAM/image/p03-181-02.jpg
#   inflating: iam-trocr/IAM/image/p03-181-03.jpg
#   inflating: iam-trocr/IAM/image/p03-181-04.jpg
#   inflating: iam-trocr/IAM/image/p03-181-05.jpg
#   inflating: iam-trocr/IAM/image/p03-181-06.jpg
#   inflating: iam-trocr/IAM/image/p03-181-07.jpg
#   inflating: iam-trocr/IAM/image/p03-181-08.jpg
#   inflating: iam-trocr/IAM/image/p03-181-09.jpg
#   inflating: iam-trocr/IAM/image/p03-189-00.jpg
#   inflating: iam-trocr/IAM/image/p03-189-01.jpg
#   inflating: iam-trocr/IAM/image/p03-189-02.jpg
#   inflating: iam-trocr/IAM/image/p03-189-03.jpg
#   inflating: iam-trocr/IAM/image/p03-189-04.jpg
#   inflating: iam-trocr/IAM/image/p06-030-00.jpg
#   inflating: iam-trocr/IAM/image/p06-030-01.jpg
#   inflating: iam-trocr/IAM/image/p06-030-02.jpg
#   inflating: iam-trocr/IAM/image/p06-030-03.jpg
#   inflating: iam-trocr/IAM/image/p06-030-04.jpg
#   inflating: iam-trocr/IAM/image/p06-030-05.jpg
#   inflating: iam-trocr/IAM/image/p06-030-06.jpg
#   inflating: iam-trocr/IAM/image/p06-030-07.jpg
#   inflating: iam-trocr/IAM/image/p06-030-08.jpg
#   inflating: iam-trocr/IAM/image/p06-042-00.jpg
#   inflating: iam-trocr/IAM/image/p06-042-01.jpg
#   inflating: iam-trocr/IAM/image/p06-042-02.jpg
#   inflating: iam-trocr/IAM/image/p06-042-03.jpg
#   inflating: iam-trocr/IAM/image/p06-042-04.jpg
#   inflating: iam-trocr/IAM/image/p06-042-05.jpg
#   inflating: iam-trocr/IAM/image/p06-042-06.jpg
#   inflating: iam-trocr/IAM/image/p06-042-07.jpg
#   inflating: iam-trocr/IAM/image/p06-042-08.jpg
#   inflating: iam-trocr/IAM/image/p06-042-09.jpg
#   inflating: iam-trocr/IAM/image/p06-042-10.jpg
#   inflating: iam-trocr/IAM/image/p06-047-00.jpg
#   inflating: iam-trocr/IAM/image/p06-047-01.jpg
#   inflating: iam-trocr/IAM/image/p06-047-02.jpg
#   inflating: iam-trocr/IAM/image/p06-047-03.jpg
#   inflating: iam-trocr/IAM/image/p06-047-04.jpg
#   inflating: iam-trocr/IAM/image/p06-047-05.jpg
#   inflating: iam-trocr/IAM/image/p06-047-06.jpg
#   inflating: iam-trocr/IAM/image/p06-047-07.jpg
#   inflating: iam-trocr/IAM/image/p06-047-08.jpg
#   inflating: iam-trocr/IAM/image/p06-047-09.jpg
#   inflating: iam-trocr/IAM/image/p06-047-10.jpg
#   inflating: iam-trocr/IAM/image/p06-052-00.jpg
#   inflating: iam-trocr/IAM/image/p06-052-01.jpg
#   inflating: iam-trocr/IAM/image/p06-052-02.jpg
#   inflating: iam-trocr/IAM/image/p06-052-03.jpg
#   inflating: iam-trocr/IAM/image/p06-052-04.jpg
#   inflating: iam-trocr/IAM/image/p06-052-05.jpg
#   inflating: iam-trocr/IAM/image/p06-052-06.jpg
#   inflating: iam-trocr/IAM/image/p06-052-07.jpg
#   inflating: iam-trocr/IAM/image/p06-052-08.jpg
#   inflating: iam-trocr/IAM/image/p06-058-00.jpg
#   inflating: iam-trocr/IAM/image/p06-058-01.jpg
#   inflating: iam-trocr/IAM/image/p06-058-02.jpg
#   inflating: iam-trocr/IAM/image/p06-058-03.jpg
#   inflating: iam-trocr/IAM/image/p06-058-04.jpg
#   inflating: iam-trocr/IAM/image/p06-058-05.jpg
#   inflating: iam-trocr/IAM/image/p06-058-06.jpg
#   inflating: iam-trocr/IAM/image/p06-058-07.jpg
#   inflating: iam-trocr/IAM/image/p06-058-08.jpg
#   inflating: iam-trocr/IAM/image/p06-058-09.jpg
#   inflating: iam-trocr/IAM/image/p06-058-10.jpg
#   inflating: iam-trocr/IAM/image/p06-069-00.jpg
#   inflating: iam-trocr/IAM/image/p06-069-01.jpg
#   inflating: iam-trocr/IAM/image/p06-069-02.jpg
#   inflating: iam-trocr/IAM/image/p06-069-03.jpg
#   inflating: iam-trocr/IAM/image/p06-069-04.jpg
#   inflating: iam-trocr/IAM/image/p06-069-05.jpg
#   inflating: iam-trocr/IAM/image/p06-069-06.jpg
#   inflating: iam-trocr/IAM/image/p06-069-07.jpg
#   inflating: iam-trocr/IAM/image/p06-069-08.jpg
#   inflating: iam-trocr/IAM/image/p06-069-09.jpg
#   inflating: iam-trocr/IAM/image/p06-069-10.jpg
#   inflating: iam-trocr/IAM/image/p06-088-00.jpg
#   inflating: iam-trocr/IAM/image/p06-088-01.jpg
#   inflating: iam-trocr/IAM/image/p06-088-02.jpg
#   inflating: iam-trocr/IAM/image/p06-088-03.jpg
#   inflating: iam-trocr/IAM/image/p06-088-04.jpg
#   inflating: iam-trocr/IAM/image/p06-088-05.jpg
#   inflating: iam-trocr/IAM/image/p06-088-06.jpg
#   inflating: iam-trocr/IAM/image/p06-088-07.jpg
#   inflating: iam-trocr/IAM/image/p06-088-08.jpg
#   inflating: iam-trocr/IAM/image/p06-088-09.jpg
#   inflating: iam-trocr/IAM/image/p06-096-00.jpg
#   inflating: iam-trocr/IAM/image/p06-096-01.jpg
#   inflating: iam-trocr/IAM/image/p06-096-02.jpg
#   inflating: iam-trocr/IAM/image/p06-096-03.jpg
#   inflating: iam-trocr/IAM/image/p06-096-04.jpg
#   inflating: iam-trocr/IAM/image/p06-096-05.jpg
#   inflating: iam-trocr/IAM/image/p06-096-06.jpg
#   inflating: iam-trocr/IAM/image/p06-096-07.jpg
#   inflating: iam-trocr/IAM/image/p06-096-08.jpg
#   inflating: iam-trocr/IAM/image/p06-096-09.jpg
#   inflating: iam-trocr/IAM/image/p06-096-10.jpg
#   inflating: iam-trocr/IAM/image/p06-104-00.jpg
#   inflating: iam-trocr/IAM/image/p06-104-01.jpg
#   inflating: iam-trocr/IAM/image/p06-104-02.jpg
#   inflating: iam-trocr/IAM/image/p06-104-03.jpg
#   inflating: iam-trocr/IAM/image/p06-104-04.jpg
#   inflating: iam-trocr/IAM/image/p06-104-05.jpg
#   inflating: iam-trocr/IAM/image/p06-104-06.jpg
#   inflating: iam-trocr/IAM/image/p06-104-07.jpg
#   inflating: iam-trocr/IAM/image/p06-104-08.jpg
#   inflating: iam-trocr/IAM/image/p06-104-09.jpg
#   inflating: iam-trocr/IAM/image/r03-053-00.jpg
#   inflating: iam-trocr/IAM/image/r03-053-01.jpg
#   inflating: iam-trocr/IAM/image/r03-053-02.jpg
#   inflating: iam-trocr/IAM/image/r03-053-03.jpg
#   inflating: iam-trocr/IAM/image/r03-053-04.jpg
#   inflating: iam-trocr/IAM/image/r03-053-05.jpg
#   inflating: iam-trocr/IAM/image/r03-053-06.jpg
#   inflating: iam-trocr/IAM/image/r03-053-07.jpg
#   inflating: iam-trocr/IAM/image/r03-053-08.jpg

# %% [markdown]
# ## Prepare data
#
# We first download the data. Here, I'm just using the IAM test set, as this was released by the TrOCR authors in the unilm repository. It can be downloaded from [this page](https://github.com/microsoft/unilm/tree/master/trocr).
#
# Let's make a [regular PyTorch dataset](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html). We first create a Pandas dataframe with 2 columns. Each row consists of the file name of an image, and the corresponding text.

# %%
import pandas as pd

df = pd.read_fwf('/content/iam-trocr/IAM/gt_test.txt', header=None)
df.rename(columns={0: "file_name", 1: "text"}, inplace=True)
del df[2]
# some file names end with jp instead of jpg, let's fix this
df['file_name'] = df['file_name'].apply(lambda x: x + 'g' if x.endswith('jp') else x)
df.head()
# Out:
#         file_name                                               text
# 0  c04-110-00.jpg  Become a success with a disc and hey presto ! ...
# 1  c04-110-01.jpg  assuredness " Bella Bella Marie " ( Parlophone...
# 2  c04-110-02.jpg  I don't think he will storm the charts with th...
# 3  c04-110-03.jpg  CHRIS CHARLES , 39 , who lives in Stockton-on-...
# 4  c04-116-00.jpg  He is also a director of a couple of garages ....

# %% [markdown]
# We split up the data into training + testing, using sklearn's `train_test_split` function.

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(df, test_size=0.2)
# we reset the indices to start from zero
train_df.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Each element of the dataset should return 2 things:
# * `pixel_values`, which serve as input to the model.
# * `labels`, which are the `input_ids` of the corresponding text in the image.
#
# We use `TrOCRProcessor` to prepare the data for the model. `TrOCRProcessor` is actually just a wrapper around a `ViTFeatureExtractor` (which can be used to resize + normalize images) and a `RobertaTokenizer` (which can be used to encode and decode text into/from `input_ids`).

# %%
import torch
from torch.utils.data import Dataset
from PIL import Image

class IAMDataset(Dataset):
    def __init__(self, root_dir, df, processor, max_target_length=128):
        self.root_dir = root_dir
        self.df = df
        self.processor = processor
        self.max_target_length = max_target_length

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        # get file name + text
        file_name = self.df['file_name'][idx]
        text = self.df['text'][idx]
        # prepare image (i.e. resize + normalize)
        image = Image.open(self.root_dir + file_name).convert("RGB")
        pixel_values = self.processor(image, return_tensors="pt").pixel_values
        # add labels (input_ids) by encoding the text
        labels = self.processor.tokenizer(text,
                                          padding="max_length",
                                          max_length=self.max_target_length).input_ids
        # important: make sure that PAD tokens are ignored by the loss function
        labels = [label if label != self.processor.tokenizer.pad_token_id else -100 for label in labels]

        encoding = {"pixel_values": pixel_values.squeeze(), "labels": torch.tensor(labels)}
        return encoding

# %% [markdown]
# Let's initialize the training and evaluation datasets:

# %%
from transformers import TrOCRProcessor

processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-handwritten")
train_dataset = IAMDataset(root_dir='/content/iam-trocr/IAM/image/',
                           df=train_df,
                           processor=processor)
eval_dataset = IAMDataset(root_dir='/content/iam-trocr/IAM/image/',
                           df=test_df,
                           processor=processor)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/224 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]

# %%
print("Number of training examples:", len(train_dataset))
print("Number of validation examples:", len(eval_dataset))
# Out:
# Number of training examples: 2332
# Number of validation examples: 583

# %% [markdown]
# Let's verify an example from the training dataset:

# %%
encoding = train_dataset[0]
for k,v in encoding.items():
  print(k, v.shape)
# Out:
# pixel_values torch.Size([3, 384, 384])
# labels torch.Size([128])

# %% [markdown]
# We can also check the original image and decode the labels:

# %%
image = Image.open(train_dataset.root_dir + train_df['file_name'][0]).convert("RGB")
image
# Out:
# <PIL.Image.Image image mode=RGB size=1497x128>

# %%
labels = encoding['labels']
labels[labels == -100] = processor.tokenizer.pad_token_id
label_str = processor.decode(labels, skip_special_tokens=True)
print(label_str)
# Out:
# serve Him with all your heart and with all

# %% [markdown]
# Let's create corresponding dataloaders:

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True)
eval_dataloader = DataLoader(eval_dataset, batch_size=4)

# %% [markdown]
# ## Train a model
#
# Here, we initialize the TrOCR model from its pretrained weights. Note that the weights of the language modeling head are already initialized from pre-training, as the model was already trained to generate text during its pre-training stage. Refer to the paper for details.

# %%
from transformers import VisionEncoderDecoderModel
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = VisionEncoderDecoderModel.from_pretrained("microsoft/trocr-base-stage1")
model.to(device)
# Out:
# config.json:   0%|          | 0.00/4.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.54G [00:00<?, ?B/s]
# Config of the encoder: <class 'transformers.models.vit.modeling_vit.ViTModel'> is overwritten by shared encoder config: ViTConfig {
#   "attention_probs_dropout_prob": 0.0,
#   "encoder_stride": 16,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 768,
#   "image_size": 384,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "model_type": "vit",
#   "num_attention_heads": 12,
#   "num_channels": 3,
#   "num_hidden_layers": 12,
#   "patch_size": 16,
#   "qkv_bias": false,
#   "transformers_version": "4.47.1"
# }
#
# Config of the decoder: <class 'transformers.models.trocr.modeling_trocr.TrOCRForCausalLM'> is overwritten by shared decoder config: TrOCRConfig {
#   "activation_dropout": 0.0,
#   "activation_function": "relu",
#   "add_cross_attention": true,
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "classifier_dropout": 0.0,
#   "cross_attention_hidden_size": 768,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 12,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "eos_token_id": 2,
#   "init_std": 0.02,
#   "is_decoder": true,
#   "layernorm_embedding": false,
#   "max_position_embeddings": 1024,
#   "model_type": "trocr",
#   "pad_token_id": 1,
#   "scale_embedding": true,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.47.1",
#   "use_cache": false,
#   "use_learned_position_embeddings": false,
#   "vocab_size": 50265
# }
#
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-base-stage1 and are newly initialized: ['encoder.pooler.dense.bias', 'encoder.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# generation_config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# VisionEncoderDecoderModel(
#   (encoder): ViTModel(
#     (embeddings): ViTEmbeddings(
#       (patch_embeddings): ViTPatchEmbeddings(
#         (projection): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ViTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ViTLayer(
#           (attention): ViTSdpaAttention(
#             (attention): ViTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=False)
#               (key): Linear(in_features=768, out_features=768, bias=False)
#               (value): Linear(in_features=768, out_features=768, bias=False)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (pooler): ViTPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (decoder): TrOCRForCausalLM(
#     (model): TrOCRDecoderWrapper(
#       (decoder): TrOCRDecoder(
#         (embed_tokens): TrOCRScaledWordEmbedding(50265, 1024, padding_idx=1)
#         (embed_positions): TrOCRSinusoidalPositionalEmbedding()
#         (layers): ModuleList(
#           (0-11): 12 x TrOCRDecoderLayer(
#             (self_attn): TrOCRAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (activation_fn): ReLU()
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): TrOCRAttention(
#               (k_proj): Linear(in_features=768, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=768, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (output_projection): Linear(in_features=1024, out_features=50265, bias=False)
#   )
# )

# %% [markdown]
# Importantly, we need to set a couple of attributes, namely:
# * the attributes required for creating the `decoder_input_ids` from the `labels` (the model will automatically create the `decoder_input_ids` by shifting the `labels` one position to the right and prepending the `decoder_start_token_id`, as well as replacing ids which are -100 by the pad_token_id)
# * the vocabulary size of the model (for the language modeling head on top of the decoder)
# * beam-search related parameters which are used when generating text.

# %%
# set special tokens used for creating the decoder_input_ids from the labels
model.config.decoder_start_token_id = processor.tokenizer.cls_token_id
model.config.pad_token_id = processor.tokenizer.pad_token_id
# make sure vocab size is set correctly
model.config.vocab_size = model.config.decoder.vocab_size

# set beam search parameters
model.config.eos_token_id = processor.tokenizer.sep_token_id
model.config.max_length = 64
model.config.early_stopping = True
model.config.no_repeat_ngram_size = 3
model.config.length_penalty = 2.0
model.config.num_beams = 4

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.2.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.9.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.11.10)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.3 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3

# %% [markdown]
# We will evaluate the model on the Character Error Rate (CER), which is available in HuggingFace Datasets (see [here](https://huggingface.co/metrics/cer)).

# %%
from evaluate import load

cer_metric = load("cer")
# Out:
# Downloading builder script:   0%|          | 0.00/5.60k [00:00<?, ?B/s]

# %%
def compute_cer(pred_ids, label_ids):
    pred_str = processor.batch_decode(pred_ids, skip_special_tokens=True)
    label_ids[label_ids == -100] = processor.tokenizer.pad_token_id
    label_str = processor.batch_decode(label_ids, skip_special_tokens=True)

    cer = cer_metric.compute(predictions=pred_str, references=label_str)

    return cer

# %%
from transformers import AdamW
from tqdm.notebook import tqdm

optimizer = AdamW(model.parameters(), lr=5e-5)

for epoch in range(10):  # loop over the dataset multiple times
   # train
   model.train()
   train_loss = 0.0
   for batch in tqdm(train_dataloader):
      # get the inputs
      for k,v in batch.items():
        batch[k] = v.to(device)

      # forward + backward + optimize
      outputs = model(**batch)
      loss = outputs.loss
      loss.backward()
      optimizer.step()
      optimizer.zero_grad()

      train_loss += loss.item()


   print(f"Loss after epoch {epoch}:", train_loss/len(train_dataloader))

   # evaluate
   model.eval()
   valid_cer = 0.0
   with torch.no_grad():
     for batch in tqdm(eval_dataloader):
       # run batch generation
       outputs = model.generate(batch["pixel_values"].to(device))
       # compute metrics
       cer = compute_cer(pred_ids=outputs, label_ids=batch["labels"])
       valid_cer += cer

   print("Validation CER:", valid_cer / len(eval_dataloader))

model.save_pretrained(".")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   0%|          | 0/583 [00:00<?, ?it/s]
# Loss after epoch 0: 4.653985083614369
#   0%|          | 0/146 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1527: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed in v5. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# Validation CER: 0.5102817312058231
#   0%|          | 0/583 [00:00<?, ?it/s]
# Loss after epoch 1: 3.0519099591322254
#   0%|          | 0/146 [00:00<?, ?it/s]
# Validation CER: 0.5133476906494508
#   0%|          | 0/583 [00:00<?, ?it/s]
# Loss after epoch 2: 2.3411370939087908
#   0%|          | 0/146 [00:00<?, ?it/s]
# Validation CER: 0.43733636927989966
#   0%|          | 0/583 [00:00<?, ?it/s]
# Loss after epoch 3: 1.9114817297070146
#   0%|          | 0/146 [00:00<?, ?it/s]
# Validation CER: 0.6781227814100642
#   0%|          | 0/583 [00:00<?, ?it/s]
# Loss after epoch 4: 1.3438787250228443
#   0%|          | 0/146 [00:00<?, ?it/s]
# Validation CER: 0.37023471424471827
#   0%|          | 0/583 [00:00<?, ?it/s]
# Loss after epoch 5: 1.2279980337537992
#   0%|          | 0/146 [00:00<?, ?it/s]
# Validation CER: 0.45350293694131394
#   0%|          | 0/583 [00:00<?, ?it/s]
# Loss after epoch 6: 1.1752910100779852
#   0%|          | 0/146 [00:00<?, ?it/s]
# Validation CER: 0.41139677298569327
#   0%|          | 0/583 [00:00<?, ?it/s]
# Loss after epoch 7: 1.0248732175262674
#   0%|          | 0/146 [00:00<?, ?it/s]
# Validation CER: 0.5676481369120666
#   0%|          | 0/583 [00:00<?, ?it/s]
# Loss after epoch 8: 1.4682829984772061
#   0%|          | 0/146 [00:00<?, ?it/s]
# Validation CER: 0.4674569800583891
#   0%|          | 0/583 [00:00<?, ?it/s]
# Loss after epoch 9: 1.1303251582496572
#   0%|          | 0/146 [00:00<?, ?it/s]
# Validation CER: 0.5792609364648628
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2817: UserWarning: Moving the following attributes in the config to the generation config: {'max_length': 64, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(

# %% [markdown]
# ## Inference
#
# Note that after training, you can easily load the model using the .`from_pretrained(output_dir)` method.
#
# For inference on new images, I refer to my inference notebook, that can also be found in my [Transformers Tutorials repository](https://github.com/NielsRogge/Transformers-Tutorials) on Github.
